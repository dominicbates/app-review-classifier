# %% [markdown]
# ### Load modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from gensim.models.word2vec import Word2Vec
from gensim.models.phrases import Phrases, Phraser
from gensim.utils import simple_preprocess
import spacy

# import spacy
# %config InlineBackend.figure_format = 'retina'
plt.style.use('ggplot')

# %% [markdown]
# ### Load data and create fake categories

# %%
reviews_df = pd.read_parquet('/Users/dominicbates/Documents/GitHub/app-review-classifier/data/reviews_sample.parquet')

# %%
reviews_df['classification'] = ''
reviews_df.loc[(reviews_df['rating']>=4), ['classification']] = 'Positive'
reviews_df.loc[(reviews_df['rating']<=2), ['classification']] = 'Negative'
reviews_df.loc[(reviews_df['rating']==3), ['classification']] = 'Mixed'

# %%
reviews_df.sample(500,random_state=1)['review'].iloc[66]


# # Main topics:
# - Bug reports "This thing is broken"
# - 1/2 word positive review, e.g. "Great", "Nice App"
# - Positive review "Amazing journalism... great app..."
# - Negative feedback "Too expensive... not very good..."
# - Suggestions "I wish..."
# - Mixed "Great app, but X..." "Love the economist, but..."

# Coule have:
# Categories:
# Bug report, positive feedback, negative feedback (non-bug report), short comment, mixed

# Or could have:
# Sentiment: positive, negative, mixed
# Type: bug report, feedback, short comment, mixed...

# Could aslso split by journalism vs app vs subscription/price?
# What happens is it's like great app, but this specific thing is broken?
# Out:
# 'Great overview; down to the point.'

# %%
reviews_df.sample(500,random_state=1)[['date','rating','app','review']].to_csv('/Users/dominicbates/Documents/GitHub/app-review-classifier/data/sample_review_data.csv', index=False)

# %%
reviews_df.sample(200,random_state=1)[['date','rating','app','review']]
# Out:
#                      date  rating                     app  \
# 316   2021-01-04 13:03:44       1   The Economist (Apple)
# 1117  2021-05-14 21:35:36       1   The Economist (Apple)
# 10390 2018-08-24 09:34:28       5       Espresso (Google)
# 2223  2021-09-19 15:26:18       5   The Economist (Apple)
# 14985 2014-11-06 16:32:18       5       Espresso (Google)
# ...                   ...     ...                     ...
# 11219 2017-10-16 18:27:48       5       Espresso (Google)
# 13922 2016-03-26 10:09:28       5       Espresso (Google)
# 10491 2018-07-23 17:53:14       4       Espresso (Google)
# 13519 2016-04-15 20:05:38       5       Espresso (Google)
# 6130  2021-11-12 04:10:18       5  The Economist (Google)
#
#                                                   review
# 316    I have been using the app for several years an...
# 1117   Version 3.0.3 is garbage: unresponsive for a f...
# 10390                                              Great
# 2223                                               Super
# 14985                                          Well Done
# ...                                                  ...
# 11219    good mix of topics short and brief to the point
# 13922              A useful different take on world news
# 10491  Nice interesting selection of daily news snipp...
# 13519  The reading time exactly matches my commute. M...
# 6130   Great writing, excellent content. Just an all ...
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Set up samples

# %%
m_train = (reviews_df['date'] < '2021-06-01')
m_valid = (reviews_df['date'] >= '2021-06-01') & (reviews_df['date'] < '2022-01-01')
m_test = (reviews_df['date'] >= '2022-01-01')

print('Total data size:',len(reviews_df))
print('----------------------')
print('Training size:',m_train.sum())
print('Validation size:',m_valid.sum())
print('Test size:',m_test.sum())

df_train = reviews_df[m_train].reset_index(drop=True)
df_valid = reviews_df[m_valid].reset_index(drop=True)
df_test = reviews_df[m_test].reset_index(drop=True)
# Out:
# Total data size: 14986
# ----------------------
# Training size: 11911
# Validation size: 1619
# Test size: 1456

# %% [markdown]
# ### Embedder class

# %%
# # Default embedder configs
# default_configs = {'tfidf':{'min_df':5, # Min number of occurances of word to consider
#                             'ngram_range':(1, 1)}, # Ngram range
                   
#                    'word2vec':{'min_count':5, # Min number of occurances of word to consider
#                                'vector_size':100, # Dimension of embedding matrix (i.e. number of embedding features)
#                                'window':5, # Size of window to consider
#                                'workers':3, # Number of partitions during training
#                                'sg':1}, # Training algorothm (CBOW(0) or skip gram(1))
                   
#                    'glove':{}}


# # Custom stop words
# my_stop_words = ({'namely', 'between', 'up', 'whither', 'them', 'beside', 'your', 'about', 'hence', 'former', 'ours', 'itself', 'or', 'these', 'their', 'those', 'has', 're', 'next', 'hereupon', 'whether', 'latter', 'towards', 'over', 'yourselves', 'himself', 'beforehand', 'you', 'wherever', 'another', 'than', 'do', 'around', 'him', 'upon', 'been', 'an', 'me', 'toward', 'within', 'of', 'whole', 'ca', 'once', 'nor', 'thru', 'seeming', 'already', 'keep', 'so', 'mine', 'others', 'until', 'move', 'ourselves', 'other', 'where', 'thereupon', 'she', 'am', 'without', 'again', 'hereby', 'be', 'someone', 'sometime', 'used', 'go', 'everyone', 'some', 'then', 'see', 'to', 'seemed', 'i', 'become', 'whatever', 'and', 'what', 'that', 'thence', 'too', 'whenever', 'whereupon', 'can', 'his', 'just', 'due', 'thereby', 'done', 'name', 'none', 'part', 'noone', 'since', 'doing', 'meanwhile', 'via', 'herself', 'also', 'amount', 'seems', 'say', 'get', 'through', 'show', 'made', 'such', 'a', 'as', 'hers', 'the', 'my', 'whereafter', 'in', 'themselves', 'which', 'something', 'put', 'it', 'by', 'may', 'who', 'various', 'whence', 'throughout', 'during', 'hereafter', 'had', 'after', 'under', 'few', 'using', 'whom', 'will', 'though', 'its', 'might', 'across', 'most', 'above', 'how', 'regarding', 'being', 'our', 'afterwards', 'behind', 'make', 'almost', 'each', 'side', 'along', 'much', 'while', 'any', 'elsewhere', 'many', 'this', 'own', 'us', 'would', 'does', 'latterly', 'anything', 'when', 'are', 'with', 'onto', 'even', 'did', 'thereafter', 'yours', 'all', 'is', 'third', 'if', 'somewhere', 'nothing', 'because', 'wherein', 'whoever', 'somehow', 'either', 'every', 'out', 'whose', 'front', 'take', 'both', 'they', 'for', 'empty', 'anyone', 'back', 'formerly', 'whereby', 'full', 'here', 'into', 'myself', 'we', 'became', 'from', 'seem', 'anywhere', 'besides', 'herein', 'ever', 'at', 'her', 'must', 'therein', 'nobody','well', 'give', 'per', 'indeed', 'down', 'still', 'on', 'could', 'although', 'amongst', 'there', 'was', 'else', 'first', 'further', 'have', 'several', 'yourself', 'beyond', 'now'}
#                  | {'ill','i','id','ive','im','mine'} | 
#                  {'you','youll','youre','your','youd','youve','yours'} | 
#                  {'he','hell','hes','hed','his'} | 
#                  {'she','shell','shed','hers'} |
#                  {'they','theyre','theyd','their','theirs','theyve'} |
#                  {'weve','wed','well','our','ours'} |
#                  {'isnt','wont','shant','d','x'})



# class Embedder:
#     '''
#     Class for performing embedding (TFIDF) on clean text
#     '''
#     def __init__(self,
#                  method='tfidf',
#                  config = None):

#         # Check method exists
#         possible_methods = ['tfidf','word2vec','glove']
#         if method not in possible_methods:
#             raise ValueError('Method not recognised. try one of: '+str(possible_methods))
#         else:
#             self.method = method
            
#         # Set config params
#         if config is None:
#             self.config = default_configs[method]
#         else:
#             self.config = config
            
#         # Set up models
#         if self.method is 'tfidf':
#             self.embedder = TfidfVectorizer(min_df=self.config['min_df'], 
#                                             ngram_range=self.config['ngram_range'])
#         elif self.method is 'word2vec':
#             self.embedder = None # Gets created when training
#         elif self.method is 'glove':
#             print('not done yet')
        
        
#     def remove_stopwords_row(self, doc, min_n=3):
#         '''
#         Removes stop words from single row (e.g. 'here is some text')
#         '''
#         txt = [token for token in doc if token not in my_stop_words]
#         # return None if not enough words left
#         if len(txt) >= min_n:
#             return ' '.join(txt)
#         else:
#             return None
    
    
#     def remove_stopwords(self, text_df):

#         '''
#         Cleans whole text column and removes stop words e.g. df['cleaned_text'] = remove_stopwords(df['raw_text'])
#         '''
#         print('Cleaning up text...')
#         t1 = time.time()
#         cleaned_text = [re.sub("[^a-zA-Z ]", '', str(row)).lower() for row in text_df] # Doesn't do anything for this dataset (remove non alpha-numeric?)
#         cleaned_text = [re.sub(' +', ' ', str(row)).lower().lstrip(' ') for row in cleaned_text] # Remove multiple spaces
#         cleaned_text = [self.remove_stopwords_row(doc.split(' ')) for doc in cleaned_text] # Remove stop words
#         print('Text cleaned in: {} seconds'.format(round((time.time() - t1), 2)))

#         return cleaned_text

    
#     def lemmatization(self, texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):

#         # Load model
#         print('Loading spacy model...')
#         nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
#         print('Model loaded!')
        
#         texts_out = []
#         for sent in texts:
#             doc = nlp(" ".join(sent)) 
#             texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
        
#         return texts_out
        
        
        
#     def process_raw_text(self, raw_text, ngram_threshold=200):

#         def sentence_to_words(sentences):
#             for sentence in sentences:
#                 yield(simple_preprocess(str(sentence), deacc=True, min_len=1, max_len=20))  # deacc=True removes punctuations

#         # Remove stop words
#         cleaned_text = test_embedder.remove_stopwords(df_train['review'])

#         # Turn to list of words and remove punctuation
#         words = list(sentence_to_words(cleaned_text))

#         # Build the bigram and trigram models
#         bigram = Phrases(words, min_count=1, threshold=ngram_threshold) # higher threshold fewer phrases.
#         trigram = Phrases(bigram[words], min_count=1, threshold=ngram_threshold)  
#         bigram_mod = Phraser(bigram)
#         trigram_mod = Phraser(trigram)
        
#         # Get final word list
#         words_and_ngrams = [trigram_mod[bigram_mod[doc]] for doc in words]
        
#         # Lemmatise
#         final_words_lemmatised = self.lemmatization(words_and_ngrams)

#         return final_words_lemmatised
        
        
        
#     def fit(self, text):
#         if self.method is 'tfidf':
#             self.embedder.fit(text)
#         elif self.method is 'word2vec':
#             self.embedder = Word2Vec(text, 
#                                      min_count=self.config['min_count'],
#                                      vector_size = self.config['vector_size'],
#                                      workers = self.config['workers'],
#                                      window = self.config['window'],
#                                      sg = self.config['sg'])
#             print('not done yet')
#         elif self.method is 'glove':
#             print('not done yet')
            
            
#     def apply(self, text):
#         if self.method is 'tfidf':
#             return self.embedder.transform(text)
#         elif self.method is 'word2vec':
#             print('not done yet')
#         elif self.method is 'glove':
#             print('not done yet')

# %%
# # Default embedder configs
# default_configs = {'tfidf':{'min_df':5, # Min number of occurances of word to consider
#                             'ngram_range':(1, 1)}, # Ngram range
                   
#                    'word2vec':{'min_count':5, # Min number of occurances of word to consider
#                                'vector_size':100, # Dimension of embedding matrix (i.e. number of embedding features)
#                                'window':5, # Size of window to consider
#                                'workers':3, # Number of partitions during training
#                                'sg':1}, # Training algorothm (CBOW(0) or skip gram(1))
                   
#                    'glove':{}}


# Custom stop words
my_stop_words = ({'namely','between','up','whither','them','beside','your','about','hence','former','ours','itself','or','these','their','those','has','re','next','hereupon','whether','latter','towards','over','yourselves','himself','beforehand','you','wherever','another','than','do','around','him','upon','been','an','me','toward','within','of','whole','ca','once','nor','thru','seeming','already','keep','so','mine','others','until','move','ourselves','other','where','thereupon','she','am','without','again','hereby','be','someone','sometime','used','go','everyone','some','then','see','to','seemed','i','become','whatever','and','what','that','thence','too','whenever','whereupon','can','his','just','due','thereby','done','name','none','part','noone','since','doing','meanwhile','via','herself','also','amount','seems','say','get','through','show','made','such','a','as','hers','the','my','whereafter','in','themselves','which','something','put','it','by','may','who','various','whence','throughout','during','hereafter','had','after','under','few','using','whom','will','though','its','might','across','most','above','how','regarding','being','our','afterwards','behind','make','almost','each','side','along','much','while','any','elsewhere','many','this','own','us','would','does','latterly','anything','when','are','with','onto','even','did','thereafter','yours','all','is','third','if','somewhere','nothing','because','wherein','whoever','somehow','either','every','out','whose','front','take','both','they','for','empty','anyone','back','formerly','whereby','full','here','into','myself','we','became','from','seem','anywhere','besides','herein','ever','at','her','must','therein','nobody','well','give','per','indeed','down','still','on','could','although','amongst','there','was','else','first','further','have','several','yourself','beyond','now'}
                 | {'ill','i','id','ive','im','mine', 'you','youll','youre','your','youd','youve','yours', 'he','hell','hes','hed','his','she','shell','shed','hers','they','theyre','theyd','their','theirs','theyve','weve','wed','well','our','ours','isnt','wont','shant','d','x'})



class TextCleaner:
    def __init__(self, 
                 config=None):
        
        self.bigram_model = None
        self.trigram_model = None
        
        # Set config params
        if config is None:
            self.config = default_configs['textcleaner']
        else:
            self.config = config
        self.use_stop_words = self.config['stop_words']
        self.use_ngrams = self.config['ngrams']
        self.use_lemmatization = self.config['lemmatization']
        
    def remove_stopwords_row(self, doc, min_n=3):
        '''
        Removes stop words from single row (e.g. 'here is some text')
        '''
        txt = [token for token in doc if token not in my_stop_words]
        # return None if not enough words left
        if len(txt) >= min_n:
            return ' '.join(txt)
        else:
            return None
    
    
    def remove_stopwords(self, text_df):

        '''
        Cleans whole text column and removes stop words e.g. df['cleaned_text'] = remove_stopwords(df['raw_text'])
        '''
        print('\nCleaning up text and removing stopwords...')
        t1 = time.time()
        cleaned_text = [re.sub("[^a-zA-Z ]", '', str(row)).lower() for row in text_df] # Doesn't do anything for this dataset (remove non alpha-numeric?)
        cleaned_text = [re.sub(' +', ' ', str(row)).lower().lstrip(' ') for row in cleaned_text] # Remove multiple spaces
        cleaned_text = [self.remove_stopwords_row(doc.split(' ')) for doc in cleaned_text] # Remove stop words
        print('Text cleaned in: {} seconds'.format(round((time.time() - t1), 2)))

        return cleaned_text

    
    def lemmatization(self, texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):

        # Load model
        print('\nLoading spacy model...')
        t1 = time.time()
        nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
        print('Model loaded in: {} seconds'.format(round((time.time() - t1), 2)))
        
        # Lemmatize text
        print('\nLemmasizing...')
        t1 = time.time()
        
        texts_out = []
        for sent in texts:
            doc = nlp(" ".join(sent)) 
            texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
        
        print('Lemmatizing done in: {} seconds'.format(round((time.time() - t1), 2)))
        return texts_out
        
        
    def train_ngrams(self, words, ngram_threshold):
        # Build the bigram and trigram models
        print('\nTraining ngrams...')
        t1 = time.time()

        bigram = Phrases(words, min_count=1, threshold=ngram_threshold) # higher threshold fewer phrases.
        trigram = Phrases(bigram[words], min_count=1, threshold=ngram_threshold)  
        self.bigram_model = Phraser(bigram)
        self.trigram_model = Phraser(trigram)

        print('Training done in: {} seconds'.format(round((time.time() - t1), 2)))


    def process_raw_text(self, raw_text, 
                               train_ngrams = False, 
                               ngram_threshold=200):

        def sentence_to_words(sentences):
            for sentence in sentences:
                yield(simple_preprocess(str(sentence), deacc=True, min_len=1, max_len=20))  # deacc=True removes punctuations

        # Remove stop words (if required)
        if self.use_stop_words == True:
            cleaned_text = self.remove_stopwords(raw_text)
        else:
            cleaned_text = raw_text

        # Turn to list of words and remove punctuation
        words = list(sentence_to_words(cleaned_text))

        # Retrain ngrams (if required)
        if train_ngrams == True:
            self.train_ngrams(words, ngram_threshold)
            
        # Apply ngrams (if required)
        if self.use_ngrams == True:
            if self.bigram_model is None:
                raise ValueError('Bigram/Trigram models not trained yet! Set train_ngrams=True when calling process_raw_text() to train and save the ngram models')
            else:
                words = [self.trigram_model[self.bigram_model[doc]] for doc in words]
        
        # Lemmatise (if required)
        if self.use_lemmatization == True:
            final_words = self.lemmatization(words)
        else:
            final_words = words

        return final_words


        
#     def fit(self, text):
#         if self.method is 'tfidf':
#             self.embedder.fit(text)
#         elif self.method is 'word2vec':
#             self.embedder = Word2Vec(text, 
#                                      min_count=self.config['min_count'],
#                                      vector_size = self.config['vector_size'],
#                                      workers = self.config['workers'],
#                                      window = self.config['window'],
#                                      sg = self.config['sg'])
#             print('not done yet')
#         elif self.method is 'glove':
#             print('not done yet')
            
            
#     def apply(self, text):
#         if self.method is 'tfidf':
#             return self.embedder.transform(text)
#         elif self.method is 'word2vec':
#             print('not done yet')
#         elif self.method is 'glove':
#             print('not done yet')

# %%
# Default embedder configs
default_configs = {'textcleaner':{'stop_words':True,
                                  'ngrams':True,
                                  'lemmatization':False},
    
                   'tfidf':{'min_df':5, # Min number of occurances of word to consider
                            'ngram_range':(1, 1)}, # Ngram range
                   
                   'word2vec':{'min_count':5, # Min number of occurances of word to consider
                               'vector_size':50, # Dimension of embedding matrix (i.e. number of embedding features)
                               'window':5, # Size of window to consider
                               'workers':4, # Number of partitions during training
                               'sg':1}} # Training algorothm (CBOW(0) or skip gram(1))


class Embedder:
    '''
    Class for performing embedding on cleaned text. Can use TfidfVectorizer or word2vec
    '''
    def __init__(self,
                 method='tfidf',
                 config = None):

        # Check method exists
        possible_methods = ['tfidf','word2vec']
        if method not in possible_methods:
            raise ValueError('Method not recognised. try one of: '+str(possible_methods))
        else:
            self.method = method
            
        # Set config params
        if config is None:
            self.config = default_configs[method]
        else:
            self.config = config
            
        # Set up models
        if self.method is 'tfidf':
            self.embedder = TfidfVectorizer(min_df=self.config['min_df'], 
                                            ngram_range=self.config['ngram_range'])
        elif self.method is 'word2vec':
            self.embedder = None # Gets created when training
        elif self.method is 'glove':
            print('not done yet')
        
        
    def fit(self, sentences):
        
        if self.method is 'tfidf':
            self.embedder.fit([' '.join(sentence) for sentence in sentences]) # Requires single string with spaces
            
        elif self.method is 'word2vec':
            print('Word2Vec: Setting up model...')
            self.embedder = Word2Vec(min_count=self.config['min_count'],
                                     vector_size = self.config['vector_size'],
                                     workers = self.config['workers'],
                                     window = self.config['window'],
                                     sg = self.config['sg'])
            print('Done!\nWord2Vec: Building Vocab...')
            self.embedder.build_vocab(sentences, progress_per=1000)
            print('Done!\nWord2Vec: Training Model...')
            self.embedder.train(sentences, total_examples=self.embedder.corpus_count, epochs=50, report_delay=1)
            print('Done!')
            
            
    def apply(self, sentences):
        
        if self.method is 'tfidf':
            return self.embedder.transform([' '.join(sentence) for sentence in sentences]) # Requires single string with spaces
        
        elif self.method is 'word2vec':
            
            words = set(test_embedder.embedder.wv.index_to_key)

            # Get vectors of each word
            word_vectors = np.array([np.array([test_embedder.embedder.wv[i] for i in ls if i in words])
                                     for ls in input_sentences], dtype=object)
            # Average this for all sentences
            sentence_vectors = []
            for v in word_vectors:
                if v.size > 1:
                    sentence_vectors.append(v.mean(axis=0))
                else:
                    sentence_vectors.append(np.zeros(self.config['vector_size'], dtype=float))


            return np.array(sentence_vectors)

# %%
# test_embedder.fit(df_train['review'])
# test_embedder.apply(df_train['review'])

# Clean text
import logging
logging.basicConfig(level=logging.INFO)
text_cleaner = TextCleaner()
input_sentences = text_cleaner.process_raw_text(df_train['review'],
                                                train_ngrams = True)
# test_embedder = Embedder(method = 'tfidf')
# test_embedder.fit(input_sentences)
# test_embedder.apply(input_sentences)
test_embedder = Embedder(method = 'word2vec')
test_embedder.fit(input_sentences)
test_embedder.apply(input_sentences)
# Out:
# Cleaning up text...
# Text cleaned in: 0.18 seconds
# INFO:gensim.models.phrases:collecting all words and their counts
# INFO:gensim.models.phrases:PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO:gensim.models.phrases:PROGRESS: at sentence #10000, processed 117964 words and 77352 word types
# INFO:gensim.models.phrases:collected 84906 token types (unigram + bigrams) from a corpus of 134591 words and 11911 sentences
# INFO:gensim.models.phrases:merged Phrases<84906 vocab, min_count=1, threshold=200, max_vocab_size=40000000>
# INFO:gensim.utils:Phrases lifecycle event {'msg': 'built Phrases<84906 vocab, min_count=1, threshold=200, max_vocab_size=40000000> in 0.17s', 'datetime': '2022-08-17T15:25:47.056761', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'created'}
# INFO:gensim.models.phrases:collecting all words and their counts
# INFO:gensim.models.phrases:PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO:gensim.models.phrases:PROGRESS: at sentence #10000, processed 116043 words and 77687 word types
# INFO:gensim.models.phrases:collected 85338 token types (unigram + bigrams) from a corpus of 132380 words and 11911 sentences
# INFO:gensim.models.phrases:merged Phrases<85338 vocab, min_count=1, threshold=200, max_vocab_size=40000000>
# INFO:gensim.utils:Phrases lifecycle event {'msg': 'built Phrases<85338 vocab, min_count=1, threshold=200, max_vocab_size=40000000> in 0.50s', 'datetime': '2022-08-17T15:25:47.555048', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'created'}
# INFO:gensim.models.phrases:exporting phrases from Phrases<84906 vocab, min_count=1, threshold=200, max_vocab_size=40000000>
# INFO:gensim.utils:FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<498 phrases, min_count=1, threshold=200> from Phrases<84906 vocab, min_count=1, threshold=200, max_vocab_size=40000000> in 0.20s', 'datetime': '2022-08-17T15:25:47.756235', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'created'}
# INFO:gensim.models.phrases:exporting phrases from Phrases<85338 vocab, min_count=1, threshold=200, max_vocab_size=40000000>
# INFO:gensim.utils:FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<499 phrases, min_count=1, threshold=200> from Phrases<85338 vocab, min_count=1, threshold=200, max_vocab_size=40000000> in 0.20s', 'datetime': '2022-08-17T15:25:47.952826', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'created'}
# INFO:gensim.utils:Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=50, alpha=0.025>', 'datetime': '2022-08-17T15:25:48.240913', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'created'}
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1000, processed 21892 words, keeping 4245 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #2000, processed 41022 words, keeping 6196 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #3000, processed 50846 words, keeping 6771 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #4000, processed 62077 words, keeping 7472 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #5000, processed 76012 words, keeping 8213 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #6000, processed 84741 words, keeping 8621 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #7000, processed 92163 words, keeping 8968 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #8000, processed 100335 words, keeping 9297 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #9000, processed 108406 words, keeping 9574 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 115803 words, keeping 9806 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #11000, processed 123699 words, keeping 10047 word types
# INFO:gensim.models.word2vec:collected 10333 word types from a corpus of 132105 raw words and 11911 sentences
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 2429 unique words (23.51% of original 10333, drops 7904)', 'datetime': '2022-08-17T15:25:48.296987', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 119878 word corpus (90.74% of original 132105, drops 12227)', 'datetime': '2022-08-17T15:25:48.297808', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 10333 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 63 most-common words
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 94092.7481861127 word corpus (78.5%% of prior 119878)', 'datetime': '2022-08-17T15:25:48.318481', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:estimated required memory for 2429 words and 50 dimensions: 2186100 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.utils:Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-08-17T15:25:48.352334', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'build_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training model with 4 workers on 2429 vocabulary and 50 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-08-17T15:25:48.353008', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'train'}
# Word2Vec: Setting up model...
# Done!
# Word2Vec: Building Vocab...
# Done!
# Word2Vec: Training Model...
# INFO:gensim.models.word2vec:EPOCH 0: training on 132105 raw words (94147 effective words) took 0.1s, 815806 effective words/s
# INFO:gensim.models.word2vec:EPOCH 1: training on 132105 raw words (93926 effective words) took 0.1s, 763732 effective words/s
# INFO:gensim.models.word2vec:EPOCH 2: training on 132105 raw words (94088 effective words) took 0.1s, 783121 effective words/s
# INFO:gensim.models.word2vec:EPOCH 3: training on 132105 raw words (93956 effective words) took 0.1s, 756126 effective words/s
# INFO:gensim.models.word2vec:EPOCH 4: training on 132105 raw words (94070 effective words) took 0.1s, 771198 effective words/s
# INFO:gensim.models.word2vec:EPOCH 5: training on 132105 raw words (94185 effective words) took 0.1s, 781740 effective words/s
# INFO:gensim.models.word2vec:EPOCH 6: training on 132105 raw words (94089 effective words) took 0.1s, 806710 effective words/s
# INFO:gensim.models.word2vec:EPOCH 7: training on 132105 raw words (94154 effective words) took 0.1s, 813055 effective words/s
# INFO:gensim.models.word2vec:EPOCH 8: training on 132105 raw words (94090 effective words) took 0.1s, 813220 effective words/s
# INFO:gensim.models.word2vec:EPOCH 9: training on 132105 raw words (94156 effective words) took 0.1s, 778090 effective words/s
# INFO:gensim.models.word2vec:EPOCH 10: training on 132105 raw words (94167 effective words) took 0.1s, 734236 effective words/s
# INFO:gensim.models.word2vec:EPOCH 11: training on 132105 raw words (94022 effective words) took 0.1s, 789960 effective words/s
# INFO:gensim.models.word2vec:EPOCH 12: training on 132105 raw words (94150 effective words) took 0.1s, 823232 effective words/s
# INFO:gensim.models.word2vec:EPOCH 13: training on 132105 raw words (94097 effective words) took 0.1s, 790324 effective words/s
# INFO:gensim.models.word2vec:EPOCH 14: training on 132105 raw words (94218 effective words) took 0.1s, 792413 effective words/s
# INFO:gensim.models.word2vec:EPOCH 15: training on 132105 raw words (94306 effective words) took 0.1s, 775557 effective words/s
# INFO:gensim.models.word2vec:EPOCH 16: training on 132105 raw words (94025 effective words) took 0.1s, 769297 effective words/s
# INFO:gensim.models.word2vec:EPOCH 17: training on 132105 raw words (94131 effective words) took 0.1s, 812608 effective words/s
# INFO:gensim.models.word2vec:EPOCH 18: training on 132105 raw words (94344 effective words) took 0.1s, 778932 effective words/s
# INFO:gensim.models.word2vec:EPOCH 19: training on 132105 raw words (94159 effective words) took 0.1s, 779259 effective words/s
# INFO:gensim.models.word2vec:EPOCH 20: training on 132105 raw words (94309 effective words) took 0.1s, 785757 effective words/s
# INFO:gensim.models.word2vec:EPOCH 21: training on 132105 raw words (94034 effective words) took 0.1s, 767145 effective words/s
# INFO:gensim.models.word2vec:EPOCH 22: training on 132105 raw words (94043 effective words) took 0.2s, 615176 effective words/s
# INFO:gensim.models.word2vec:EPOCH 23: training on 132105 raw words (94074 effective words) took 0.1s, 672837 effective words/s
# INFO:gensim.models.word2vec:EPOCH 24: training on 132105 raw words (94181 effective words) took 0.1s, 780374 effective words/s
# INFO:gensim.models.word2vec:EPOCH 25: training on 132105 raw words (94153 effective words) took 0.1s, 834283 effective words/s
# INFO:gensim.models.word2vec:EPOCH 26: training on 132105 raw words (94184 effective words) took 0.1s, 821176 effective words/s
# INFO:gensim.models.word2vec:EPOCH 27: training on 132105 raw words (94243 effective words) took 0.1s, 779610 effective words/s
# INFO:gensim.models.word2vec:EPOCH 28: training on 132105 raw words (94238 effective words) took 0.1s, 791177 effective words/s
# INFO:gensim.models.word2vec:EPOCH 29: training on 132105 raw words (94205 effective words) took 0.1s, 812253 effective words/s
# INFO:gensim.models.word2vec:EPOCH 30: training on 132105 raw words (94189 effective words) took 0.1s, 794278 effective words/s
# INFO:gensim.models.word2vec:EPOCH 31: training on 132105 raw words (94145 effective words) took 0.1s, 771078 effective words/s
# INFO:gensim.models.word2vec:EPOCH 32: training on 132105 raw words (94218 effective words) took 0.1s, 766567 effective words/s
# INFO:gensim.models.word2vec:EPOCH 33: training on 132105 raw words (94141 effective words) took 0.1s, 788089 effective words/s
# INFO:gensim.models.word2vec:EPOCH 34: training on 132105 raw words (94102 effective words) took 0.1s, 778629 effective words/s
# INFO:gensim.models.word2vec:EPOCH 35: training on 132105 raw words (94113 effective words) took 0.1s, 629611 effective words/s
# INFO:gensim.models.word2vec:EPOCH 36: training on 132105 raw words (94038 effective words) took 0.1s, 745018 effective words/s
# INFO:gensim.models.word2vec:EPOCH 37: training on 132105 raw words (94161 effective words) took 0.1s, 796751 effective words/s
# INFO:gensim.models.word2vec:EPOCH 38: training on 132105 raw words (94046 effective words) took 0.1s, 794155 effective words/s
# INFO:gensim.models.word2vec:EPOCH 39: training on 132105 raw words (94091 effective words) took 0.1s, 782950 effective words/s
# INFO:gensim.models.word2vec:EPOCH 40: training on 132105 raw words (94021 effective words) took 0.1s, 687365 effective words/s
# INFO:gensim.models.word2vec:EPOCH 41: training on 132105 raw words (94033 effective words) took 0.1s, 768274 effective words/s
# INFO:gensim.models.word2vec:EPOCH 42: training on 132105 raw words (93965 effective words) took 0.1s, 816474 effective words/s
# INFO:gensim.models.word2vec:EPOCH 43: training on 132105 raw words (94088 effective words) took 0.1s, 722456 effective words/s
# INFO:gensim.models.word2vec:EPOCH 44: training on 132105 raw words (94074 effective words) took 0.1s, 653741 effective words/s
# INFO:gensim.models.word2vec:EPOCH 45: training on 132105 raw words (94078 effective words) took 0.1s, 762758 effective words/s
# INFO:gensim.models.word2vec:EPOCH 46: training on 132105 raw words (94099 effective words) took 0.1s, 821878 effective words/s
# INFO:gensim.models.word2vec:EPOCH 47: training on 132105 raw words (94211 effective words) took 0.1s, 800481 effective words/s
# INFO:gensim.models.word2vec:EPOCH 48: training on 132105 raw words (94207 effective words) took 0.1s, 734281 effective words/s
# INFO:gensim.models.word2vec:EPOCH 49: training on 132105 raw words (94156 effective words) took 0.1s, 741911 effective words/s
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training on 6605250 raw words (4706320 effective words) took 6.5s, 719254 effective words/s', 'datetime': '2022-08-17T15:25:54.897018', 'gensim': '4.2.0', 'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]', 'platform': 'Darwin-19.6.0-x86_64-i386-64bit', 'event': 'train'}
# Done!
# array([[-0.08024027, -0.00156436,  0.0378052 , ..., -0.17058206,
#          0.13666224,  0.0883866 ],
#        [-0.14573821, -0.07508348, -0.09012739, ..., -0.08947746,
#          0.28290763,  0.2316771 ],
#        [-0.20022322, -0.17697008, -0.14460512, ..., -0.19816059,
#          0.05982444,  0.1092599 ],
#        ...,
#        [-0.11474831,  0.03621515, -0.05771099, ..., -0.03151458,
#          0.16252038,  0.05168508],
#        [-0.05519113, -0.05267667, -0.17226692, ..., -0.21060862,
#          0.23082063,  0.12517489],
#        [-0.01745497,  0.00426032, -0.00174709, ...,  0.01497765,
#         -0.00139504, -0.00324988]])

# %%
# size = 50

# words = set(test_embedder.embedder.wv.index_to_key)

# word_vectors = np.array([np.array([test_embedder.embedder.wv[i] for i in ls if i in words])
#                          for ls in input_sentences], dtype=object)
# sentence_vectors = []
# for v in word_vectors:
#     if v.size > 1:
#         sentence_vectors.append(v.mean(axis=0))
#     else:
#         sentence_vectors.append(np.zeros(50, dtype=float))



# X_test_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
#                          for ls in X_test])

# %%
# np.array(sentence_vectors)

# %%
# 50 embedding size
test_embedder.embedder.wv.most_similar('absolute')
# Out:
# [('experience', 0.6580408215522766),
#  ('app', 0.6275638341903687),
#  ('religiously', 0.6201767921447754),
#  ('cause', 0.6189985871315002),
#  ('gotten', 0.6082072854042053),
#  ('implementation', 0.5763404369354248),
#  ('content', 0.5664331912994385),
#  ('intuitive', 0.5533095598220825),
#  ('largely', 0.5527818202972412),
#  ('nearly', 0.5476468205451965)]

# %%
test_cleaner = TextCleaner()
# test_embedder.fit(df_train['review'])
# test_embedder.apply(df_train['review'])

# %%
test_cleaner.process_raw_text(df_train['review'],
                               apply_stop_words = False,
                               apply_ngrams = False,
                               apply_lemmatization = False,
                               train_ngrams = False)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-241-3189f5886cdc> in <module>
#       3                                apply_ngrams = False,
#       4                                apply_lemmatization = False,
# ----> 5                                train_ngrams = False)
#
# <ipython-input-236-1c716e2bbead> in process_raw_text(self, raw_text, apply_stop_words, apply_ngrams, apply_lemmatization, train_ngrams, ngram_threshold)
#      97
#      98         # Turn to list of words and remove punctuation
# ---> 99         words = list(sentence_to_words(cleaned_text))
#     100
#     101         # Retrain ngrams (if required)
#
# UnboundLocalError: local variable 'cleaned_text' referenced before assignment

# %%
n_gram_threshold = 200

def sent_to_words(sentences):
    for sentence in sentences:
        yield(simple_preprocess(str(sentence), deacc=True, min_len=1, max_len=20))  # deacc=True removes punctuations


# Remove stop words
cleaned_text = test_embedder.clean_text(df_train['review'])
        
# Turn to list of words, and remove punctuation
data_words = list(sent_to_words(cleaned_text))

# Build the bigram and trigram models
bigram = Phrases(data_words, min_count=1, threshold=n_gram_threshold) # higher threshold fewer phrases.
trigram = Phrases(bigram[data_words], min_count=1, threshold=n_gram_threshold)  

bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
final_words = [trigram_mod[bigram_mod[doc]] for doc in data_words]
# Out:
# Cleaning up text...
# Text cleaned in: 0.2 seconds

# %%
final_words[24]
# Out:
# ['old',
#  'app',
#  'gold_standard',
#  'magazine',
#  'apps',
#  'functionality',
#  'perfect',
#  'let',
#  'immerse',
#  'weeks',
#  'magazine',
#  'no',
#  'distractions',
#  'felt',
#  'closer',
#  'print',
#  'version',
#  'menu_bar',
#  'top',
#  'always',
#  'visible',
#  'allowing',
#  'click',
#  'week',
#  'want',
#  'away',
#  'scroll',
#  'downread',
#  'shouldnt',
#  'refer',
#  'weekthats',
#  'section',
#  'magazine',
#  'confusing',
#  'call',
#  'magazine',
#  'app',
#  'never',
#  'listen',
#  'audio',
#  'version',
#  'why',
#  'page',
#  'dont',
#  'why',
#  'mess',
#  'perfection',
#  'use',
#  'classic',
#  'app',
#  'but',
#  'apparently',
#  'doesnt',
#  'recognize',
#  'economist',
#  'subscription',
#  'frustrating']

# %%
bigram_mod.__dict__
# Out:
# {'threshold': 300,
#  'min_count': 1,
#  'delimiter': '_',
#  'scoring': <function gensim.models.phrases.original_scorer(worda_count, wordb_count, bigram_count, len_vocab, min_count, corpus_word_count)>,
#  'connector_words': frozenset(),
#  'phrasegrams': {'college_student': 3537.75,
#   'washington_post': 1787.494736842105,
#   'york_times': 412.7375,
#   'images_advance': 303.23571428571427,
#   'portrait_mode': 317.49038461538464,
#   'restore_purchase': 851.187969924812,
#   'tried_deleting': 449.71398305084745,
#   'deleting_reinstalling': 795.99375,
#   'israel_crimes': 7075.5,
#   'social_media': 450.25909090909096,
#   'cover_cover': 318.2648896293211,
#   'went_wrong': 548.9612068965517,
#   'top_notch': 333.75,
#   'conversion_rates': 1415.1,
#   'minor_inconveniences': 975.9310344827586,
#   'customer_service': 365.25442477876106,
#   'check_marks': 379.04464285714283,
#   'accidentally_click': 355.4677033492823,
#   'web_browser': 312.15441176470586,
#   'big_fan': 402.25145772594755,
#   'gold_standard': 816.4038461538462,
#   'dark_mode': 592.0121457489878,
#   'blank_space': 482.42045454545456,
#   'internet_connection': 406.1584158415842,
#   'eat_breakfast': 340.9879518072289,
#   'check_mark': 408.2019230769231,
#   'walking_driving': 964.8409090909091,
#   'reverse_order': 347.9754098360656,
#   'step_backwards': 1675.7763157894735,
#   'table_contents': 1705.700892857143,
#   'user_friendly': 498.8246394872708,
#   'tends_crash': 336.9285714285714,
#   'charts_graphs': 505.3928571428571,
#   'graphs_accompany': 577.5918367346939,
#   'login_criteria': 362.84615384615387,
#   'teal_sections': 1061.325,
#   'create_playlist': 342.61408657373437,
#   'playlist_creation': 451.62765957446805,
#   'positive_note': 849.0600000000001,
#   'greatly_appreciated': 754.72,
#   'kill_relaunch': 7075.5,
#   'ipad_pro': 407.54879999999997,
#   'copy_paste': 771.8727272727273,
#   'battery_drain': 849.0600000000001,
#   'airplane_mode': 483.7948717948718,
#   'left_corner': 340.9879518072289,
#   'friends_family': 758.0892857142857,
#   'future_reference': 471.70000000000005,
#   'hampered_poor': 424.53000000000003,
#   'dig_deeper': 1632.8076923076924,
#   'added_bonus': 577.5918367346939,
#   'stand_alone': 312.15441176470586,
#   'vaguely_remember': 943.4000000000001,
#   'recently_resubscribed': 566.0400000000001,
#   'screen_rotation': 330.8025974025974,
#   'click_bait': 372.39473684210526,
#   'left_leaning': 681.9759036144578,
#   'accidentally_clicking': 406.2488038277512,
#   'lightning_fast': 505.3928571428571,
#   'font_size': 367.5584415584416,
#   'leave_house': 615.2608695652174,
#   'indicator_showing': 314.4666666666667,
#   'rd_party': 4717.0,
#   'iphone_xs': 375.69026548672565,
#   'night_mode': 362.84615384615387,
#   'shipment_arrive': 7075.5,
#   'rabbit_hole': 14151.0,
#   'search_engine': 553.7347826086956,
#   'storage_usage': 964.8409090909091,
#   'uninstall_reinstall': 1516.1785714285713,
#   'leaps_bounds': 21226.5,
#   'extra_large': 326.5615384615385,
#   'adult_life': 1286.4545454545455,
#   'wide_range': 424.53000000000003,
#   'fifth_star': 844.8358208955224,
#   'virtually_unusable': 499.4470588235294,
#   'look_forward': 320.583295194508,
#   'hey_guys': 744.7894736842105,
#   'juar_juar': 9434.0,
#   'sync_devices': 326.5615384615385,
#   'economically_politically': 3032.3571428571427,
#   'politically_financially': 4043.142857142857,
#   'connected_internet': 320.24893917963226,
#   'stands_alone': 998.8941176470588,
#   'united_states': 4717.0,
#   'exceeded_expectations': 7075.5,
#   'scam_charge': 428.81818181818187,
#   'book_reviews': 707.55,
#   'pro_restarted': 308.7490909090909,
#   'english_language': 1123.095238095238,
#   'aesthetically_pleasing': 8490.6,
#   'custom_playlist': 361.30212765957447,
#   'rewinding_seconds': 1010.7857142857142,
#   'highly_recommended': 494.5980582524272,
#   'contacted_developer': 326.5615384615385,
#   'hard_beat': 343.2857142857143,
#   'mistakenly_click': 372.39473684210526,
#   'thought_provoking': 1007.0392883617494,
#   'error_message': 469.2933673469388,
#   'fails_impress': 801.0,
#   'catchy_titles': 2234.3684210526317,
#   'facebook_twitter': 566.0400000000001,
#   'valuable_resource': 377.36,
#   'broadcast_outlets': 816.4038461538462,
#   'virtually_impossible': 414.1756097560976,
#   'cpu_cycles': 14151.0,
#   'helping_understand': 471.70000000000005,
#   'restore_purchases': 898.4761904761905,
#   'gets_chopped': 581.5479452054794,
#   'worth_penny': 454.85357142857146,
#   'deal_breaker': 3351.552631578947,
#   'visually_appealing': 1886.8000000000002,
#   'emailed_multiple': 353.775,
#   'piece_software': 505.3928571428571,
#   'humble_opinion': 832.4117647058823,
#   'developer_teams': 1088.5384615384614,
#   'nyt_wapo': 1572.3333333333333,
#   'outside_box': 943.4000000000001,
#   'credit_card': 4851.771428571428,
#   'mainstream_media': 361.8153409090909,
#   'xs_max': 2830.2,
#   'blank_white': 497.49609375,
#   'iphone_se': 563.5353982300885,
#   'background_activity': 449.23809523809524,
#   'hundreds_dollars': 5660.4,
#   'dev_team': 534.0,
#   'landscape_mode': 369.44335664335665,
#   'consider_adding': 505.3928571428571,
#   'definition_words': 425.593984962406,
#   'de_la': 1061.325,
#   'la_revista': 5306.625,
#   'economistcom_website': 314.4666666666667,
#   'help_desk': 663.328125,
#   'amazon_kindle': 2572.909090909091,
#   'username_password': 530.6625,
#   'decade_recently': 404.31428571428575,
#   'recently_renewed': 385.93636363636364,
#   'indication_whatsoever': 4043.142857142857,
#   'ios_devicesis': 758.0892857142857,
#   'devicesis_ploy': 10613.25,
#   'ploy_doublecharge': 14151.0,
#   'doublecharge_subscribers': 927.9344262295082,
#   'separately_ios': 303.23571428571427,
#   'blah_blah': 9434.0,
#   'high_res': 408.2019230769231,
#   'sad_sundays': 393.0833333333333,
#   'strongly_recommend': 303.23571428571427,
#   'price_hike': 653.123076923077,
#   'human_rights': 4245.3,
#   'clearly_laid': 312.15441176470586,
#   'minor_quibble': 1171.1172413793104,
#   'unknown_error': 884.4375,
#   'busy_schedule': 581.5479452054794,
#   'txt_size': 428.81818181818187,
#   'emailing_support': 301.0851063829787,
#   'web_site': 332.9647058823529,
#   'playlists_anymore': 336.9285714285714,
#   'picture_chart': 362.84615384615387,
#   'says_tin': 899.0047058823529,
#   'single_column': 480.59999999999997,
#   'attention_span': 1608.0681818181818,
#   'ie_britain': 308.7490909090909,
#   'low_resolution': 1179.25,
#   'car_journeys': 1489.578947368421,
#   'journeys_etc': 471.70000000000005,
#   'apple_carplay': 397.6861826697892,
#   'drains_battery': 1415.1,
#   'uninstalling_reinstalling': 530.6625,
#   'push_notifications': 300.375,
#   'loyal_reader': 385.93636363636364,
#   'deleting_redownloading': 1061.325,
#   'tick_mark': 907.1153846153846,
#   'advice_stick': 1886.8000000000002,
#   'sleep_timer': 2515.7333333333336,
#   'special_reports': 798.4890282131662,
#   'completely_ruins': 327.82239382239385,
#   'red_tick': 786.1666666666666,
#   'published_gmt': 808.6285714285715,
#   'bite_sized': 544.8948275862069,
#   'cancelling_sub': 311.010989010989,
#   'defeats_purpose': 2358.5,
#   'wide_ranging': 1188.684,
#   'heavily_biased': 643.2272727272727,
#   'antidote_fake': 786.1666666666666,
#   'oh_dear': 1179.25,
#   'took_advantage': 566.0400000000001,
#   'thank_goodness': 307.6304347826087,
#   'poorly_executed': 404.31428571428575,
#   'special_report': 551.3376623376623,
#   'tick_marks': 673.8571428571428,
#   'kept_assuming': 884.4375,
#   'clearing_cache': 1286.4545454545455,
#   'non_north': 808.6285714285715,
#   'north_american': 1173.815668202765,
#   'bigger_picture': 326.5615384615385,
#   'objective_packed': 307.6304347826087,
#   'larger_screens': 566.0400000000001,
#   'terms_conditions': 1415.1,
#   'dark_grey': 744.7894736842105,
#   'two_thumbs': 369.1565217391304,
#   'journal_planet': 353.775,
#   'price_admission': 653.123076923077,
#   'knowledge_dense': 424.53000000000003,
#   'instead_focusing': 382.4594594594595,
#   'broad_scope': 369.1565217391304,
#   'dark_theme': 446.8736842105263,
#   'markets_currencies': 836.5123152709359,
#   'cannot_fathom': 424.53000000000003,
#   'sound_bites': 334.93491124260356,
#   'occasional_cheeky': 1061.325,
#   'deep_dive': 908.0855614973261,
#   'published_est': 808.6285714285715,
#   'drain_battery': 424.53000000000003,
#   'bare_minimum': 6064.714285714285,
#   'exchange_rates': 2008.5290322580645,
#   'stock_ticker': 1230.5217391304348,
#   'barely_functional': 326.5615384615385,
#   'moving_slowly': 908.0855614973261,
#   'defeat_purpose': 1768.875,
#   'water_cooler': 10613.25,
#   'removing_video': 487.9655172413793,
#   'sole_purpose': 1768.875,
#   'monday_saturday': 463.1236363636364,
#   'commodity_prices': 1768.875,
#   'editorial_bent': 606.4714285714285,
#   'fatal_flaw': 2830.2,
#   'busy_professionals': 387.69863013698625,
#   'balance_brevity': 379.04464285714283,
#   'sports_art': 707.55,
#   'serves_purpose': 321.6136363636364,
#   'finger_pulse': 1179.25,
#   'real_strength': 353.775,
#   'holds_true': 1347.7142857142856,
#   'deeper_dive': 593.7482517482517,
#   'low_bandwidth': 1061.325,
#   'dive_deeper': 890.6223776223777,
#   'economists_iconic': 309.8759124087591,
#   'appropriately_named': 893.7473684210526,
#   'dismal_science': 884.4375,
#   'sparks_interest': 534.0,
#   'stock_indexes': 527.3664596273292,
#   'cutting_edge': 1415.1,
#   'room_improvement': 454.85357142857146,
#   'journalistic_standards': 356.74789915966386,
#   'leaves_feeling': 606.4714285714285,
#   'exchange_rate': 322.2239089184061,
#   'bite_size': 307.31969696969696,
#   'opportunity_cost': 449.23809523809524,
#   'triple_expresso': 382.4594594594595,
#   'failure_contact': 356.74789915966386,
#   'eating_breakfast': 464.98357064622127,
#   'notification_center': 463.9672131147541,
#   'brush_teeth': 8490.6,
#   'aptly_named': 4062.488038277512,
#   'lunch_breaks': 2425.885714285714,
#   'half_dozen': 764.918918918919,
#   'index_numbers': 1698.1200000000001,
#   'ease_navigation': 367.5584415584416,
#   'wouldnt_mind': 326.5615384615385,
#   'steep_price': 435.4153846153846,
#   'rate_higher': 312.15441176470586,
#   'roll_bed': 505.3928571428571,
#   'act_together': 884.4375,
#   'wide_breadth': 424.53000000000003,
#   'loyal_customers': 884.4375,
#   'train_ride': 1072.0454545454545,
#   'superbly_curated': 442.21875,
#   'soul_wit': 1698.1200000000001,
#   'corners_earth': 4043.142857142857,
#   'st_century': 4245.3,
#   'travelling_abroad': 2653.3125,
#   'agenda_driven': 1061.325,
#   'stating_facts': 534.0,
#   'leaves_wanting': 2021.5714285714284,
#   'arts_humanities': 2021.5714285714284,
#   'commuter_train': 786.1666666666666,
#   'uninstalled_reinstalled': 1152.5701357466064,
#   'establish_connection': 318.0,
#   'food_thought': 478.343661971831,
#   'easily_consumable': 429.9037974683544,
#   'email_address': 857.6363636363637,
#   'bitesized_chunks': 400.5,
#   'big_brother': 433.19387755102036,
#   'bbc_sky': 1845.782608695652,
#   'white_men': 1989.984375,
#   'middle_east': 786.1666666666666,
#   'broader_spectrum': 2572.909090909091,
#   'north_america': 1010.7857142857142,
#   'snap_shot': 411.3662790697674,
#   'deep_linking': 1664.8235294117646,
#   'item_requested': 1886.8000000000002,
#   'runs_smoothly': 770.4718693284937,
#   'podcast_players': 336.9285714285714,
#   'conversation_starters': 8086.285714285714,
#   'except_sunday': 491.7335907335907,
#   'title_suggests': 713.4957983193277,
#   'enter_credentials': 1516.1785714285713,
#   'sd_card': 4245.3,
#   'neatly_laid': 1326.65625,
#   'moto_g': 2021.5714285714284,
#   'live_chat': 346.55510204081634,
#   'loses_position': 362.84615384615387,
#   'letters_obscured': 10613.25,
#   'nav_bar': 684.7258064516129,
#   'resetting_password': 1061.325,
#   'galaxy_s': 880.2057416267943,
#   'insult_injury': 14151.0,
#   'samsung_galaxy': 890.6223776223777,
#   'galaxy_tab': 482.42045454545456,
#   'type_sizes': 663.328125,
#   'unnecessary_hassle': 884.4375,
#   'gone_wrong': 338.72074468085106,
#   'portrait_orientation': 1061.325,
#   'subscriptions_pricy': 1061.325,
#   'samsung_s': 343.748987854251,
#   'avios_offer': 1248.6176470588234,
#   'inapp_purchases': 857.6363636363637,
#   'blown_away': 385.93636363636364,
#   'purchasing_power': 1212.942857142857,
#   'pulls_together': 442.21875,
#   'manually_refresh': 353.775,
#   'previously_rated': 544.2692307692307,
#   'whet_appetite': 6064.714285714285,
#   'removing_reinstalling': 707.55,
#   'ideological_drama': 9434.0,
#   'left_wing': 340.9879518072289,
#   'bells_whistles': 15919.875,
#   'reasonably_priced': 3537.75,
#   'feb_th': 1061.325,
#   'hits_spot': 673.8571428571428,
#   'e_v': 551.3376623376623,
#   'message_pops': 346.55510204081634,
#   'breath_fresh': 1179.25,
#   'fresh_air': 1179.25,
#   'pixel_xl': 9434.0,
#   'stopped_updating': 344.09726443769,
#   'specific_stocks': 544.2692307692307,
#   'delve_deeper': 653.123076923077,
#   'pita_ji': 14151.0,
#   'bait_switch': 707.55,
#   'monday_friday': 1543.7454545454545,
#   'fills_gaps': 5306.625,
#   'autoplay_videos': 1698.1200000000001,
#   'watching_tv': 514.5818181818182,
#   'plain_english': 336.9285714285714,
#   'body_sensors': 9434.0,
#   'pictures_cut': 319.1954887218045,
#   'talking_points': 353.775,
#   'provoke_thought': 597.9295774647887,
#   'c_o': 2358.5,
#   'n_e': 606.4714285714285,
#   'e_r': 866.3877551020407,
#   'whets_appetite': 6064.714285714285,
#   'national_papers': 471.70000000000005,
#   'stock_index': 369.1565217391304,
#   'foreign_currency': 643.2272727272727,
#   'expert_team': 534.0,
#   'write_ups': 628.9333333333334,
#   'samsung_note': 326.5615384615385,
#   'install_nexus': 350.8512396694215,
#   'nexus_p': 1543.7454545454545,
#   'white_square': 1326.65625,
#   'duh_waste': 1010.7857142857142,
#   'galaxy_note': 385.93636363636364,
#   'running_kitkat': 1147.3783783783783},
#  'lifecycle_events': [{'msg': 'exported FrozenPhrases<365 phrases, min_count=1, threshold=300> from Phrases<84906 vocab, min_count=1, threshold=300, max_vocab_size=40000000> in 0.17s',
#    'datetime': '2022-08-16T15:43:29.200899',
#    'gensim': '4.2.0',
#    'python': '3.7.4 (default, Sep  7 2019, 18:27:02) \n[Clang 10.0.1 (clang-1001.0.46.4)]',
#    'platform': 'Darwin-19.6.0-x86_64-i386-64bit',
#    'event': 'created'}]}

# %%
# https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial/notebook

# %%
# df_train['review']

# %%
# test = [row for row in df_train['review']] # Generator object () only calculates when called vs [] which calculates now
# Doesn't do anything for our data - checked this

# %%
# def cleaning(doc, min_n=3):
#     # Lemmatizes and removes stopwords
#     # doc needs to be a spacy Doc object
#     txt = [token.lemma_ for token in doc if not token.is_stop]
#     # Word2Vec uses context words to learn the vector representation of a target word,
#     # if a sentence is only one or two words long,
#     # the benefit for the training is very small
#     if len(txt) >= min_n:
#         return ' '.join(txt)


# def cleaning(doc, min_n=3):
#     # Lemmatizes and removes stopwords
#     # doc needs to be a spacy Doc object
#     txt = [token for token in doc if token not in my_stop_words]
#     # Word2Vec uses context words to learn the vector representation of a target word,
#     # if a sentence is only one or two words long,
#     # the benefit for the training is very small
#     if len(txt) >= min_n:
#         return ' '.join(txt)

# %%
# Custom stop words
my_stop_words = ({'namely', 'between', 'up', 'whither', 'them', 'beside', 'your', 'about', 'hence', 'former', 'ours', 'itself', 'or', 'these', 'their', 'those', 'has', 're', 'next', 'hereupon', 'whether', 'latter', 'towards', 'over', 'yourselves', 'himself', 'beforehand', 'you', 'wherever', 'another', 'than', 'do', 'around', 'him', 'upon', 'been', 'an', 'me', 'toward', 'within', 'of', 'whole', 'ca', 'once', 'nor', 'thru', 'seeming', 'already', 'keep', 'so', 'mine', 'others', 'until', 'move', 'ourselves', 'other', 'where', 'thereupon', 'she', 'am', 'without', 'again', 'hereby', 'be', 'someone', 'sometime', 'used', 'go', 'everyone', 'some', 'then', 'see', 'to', 'seemed', 'i', 'become', 'whatever', 'and', 'what', 'that', 'thence', 'too', 'whenever', 'whereupon', 'can', 'his', 'just', 'due', 'thereby', 'done', 'name', 'none', 'part', 'noone', 'since', 'doing', 'meanwhile', 'via', 'herself', 'also', 'amount', 'seems', 'say', 'get', 'through', 'show', 'made', 'such', 'a', 'as', 'hers', 'the', 'my', 'whereafter', 'in', 'themselves', 'which', 'something', 'put', 'it', 'by', 'may', 'who', 'various', 'whence', 'throughout', 'during', 'hereafter', 'had', 'after', 'under', 'few', 'using', 'whom', 'will', 'though', 'its', 'might', 'across', 'most', 'above', 'how', 'regarding', 'being', 'our', 'afterwards', 'behind', 'make', 'almost', 'each', 'side', 'along', 'much', 'while', 'any', 'elsewhere', 'many', 'this', 'own', 'us', 'would', 'does', 'latterly', 'anything', 'when', 'are', 'with', 'onto', 'even', 'did', 'thereafter', 'yours', 'all', 'is', 'third', 'if', 'somewhere', 'nothing', 'because', 'wherein', 'whoever', 'somehow', 'either', 'every', 'out', 'whose', 'front', 'take', 'both', 'they', 'for', 'empty', 'anyone', 'back', 'formerly', 'whereby', 'full', 'here', 'into', 'myself', 'we', 'became', 'from', 'seem', 'anywhere', 'besides', 'herein', 'ever', 'at', 'her', 'must', 'therein', 'nobody','well', 'give', 'per', 'indeed', 'down', 'still', 'on', 'could', 'although', 'amongst', 'there', 'was', 'else', 'first', 'further', 'have', 'several', 'yourself', 'beyond', 'now'}
 | {'ill','i','id','ive','im','mine'} | 
 {'you','youll','youre','your','youd','youve','yours'} | 
 {'he','hell','hes','hed','his'} | 
 {'she','shell','shed','hers'} |
 {'they','theyre','theyd','their','theirs','theyve'} |
 {'weve','wed','well','our','ours'} |
 {'isnt','wont','shant','shall','d','x','is'})

    
# def load_spacy_model():
    
#     nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser']) # disable Named Entity Recognition for speed

#     # Custom stop words
#     my_stop_words = {'namely', 'between', 'up', 'whither', 'them', 'beside', 'your', 'about', 'hence', 'always', 'former', 'ours', 'itself', 'or', 'these', 'their', 'those', 'has', 're', 'next', 'hereupon', 'whether', 'latter', 'towards', 'over', 'yourselves', 'himself', 'beforehand', 'yet', 'you', 'more', 'wherever', 'another', 'than', 'do', 'off', 'around', 'him', 'upon', 'been', 'an', 'me', 'toward', 'within', 'of', 'whole', 'ca', 'once', 'nor', 'thru', 'seeming', 'already', 'keep', 'so', 'mine', 'others', 'one', 'until', 'move', 'ourselves', 'other', 'where', 'thereupon', 'she', 'am', 'without', 'again', 'hereby', 'rather', 'be', 'someone', 'thus', 'sometime', 'used', 'go', 'everyone', 'some', 'then', 'see', 'to', 'seemed', 'i', 'become', 'whatever', 'perhaps', 'and', 'what', 'that', 'thence', 'too', 'whenever', 'whereupon', 'can', 'his', 'just', 'due', 'thereby', 'done', 'name', 'whereas', 'none', 'part', 'noone', 'since', 'doing', 'therefore', 'meanwhile', 'via', 'herself', 'also', 'amount', 'seems', 'bottom', 'say', 'get', 'through', 'show', 'made', 'top', 'such', 'a', 'as', 'hers', 'the', 'my', 'whereafter', 'in', 'themselves', 'which', 'something', 'put', 'it', 'by', 'may', 'who', 'various', 'whence', 'throughout', 'during', 'hereafter', 'had', 'only', 'after', 'under', 'few', 'otherwise', 'using', 'whom', 'will', 'though', 'its', 'might', 'below', 'across', 'most', 'above', 'how', 'regarding', 'being', 'our', 'afterwards', 'behind', 'make', 'not', 'almost', 'each', 'side', 'along', 'much', 'while', 'any', 'but', 'elsewhere', 'many', 'this', 'own', 'us', 'would', 'does', 'latterly', 'unless', 'anything', 'when', 'are', 'enough', 'with', 'onto', 'even', 'did', 'thereafter', 'yours', 'moreover', 'all', 'is', 'third', 'anyway', 'however', 'nevertheless', 'if', 'somewhere', 'nothing', 'because', 'wherein', 'whoever', 'somehow', 'either', 'every', 'out', 'whose', 'front', 'take', 'both', 'they', 'for', 'empty', 'anyone', 'back', 'formerly', 'whereby', 'alone', 'full', 'here', 'into', 'myself', 'except', 'we', 'became', 'from', 'seem', 'anywhere', 'besides', 'herein', 'ever', 'at', 'her', 'must', 'therein', 'nobody','well', 'give', 'per', 'indeed', 'down', 'still', 'on', 'could', 'although', 'anyhow', 'amongst', 'there', 'often', 'was', 'else', 'first', 'further', 'no', 'have', 'several', 'yourself', 'beyond', 'now'}
#     my_stop_words = (my_stop_words | 
#      {'ill','i','id','ive','im','mine'} | 
#      {'you','youll','youre','your','youd','youve','yours'} | 
#      {'he','hell','hes','hed','his'} | 
#      {'she','shell','shed','hers'} |
#      {'they','theyre','theyd','their','theirs','theyve'} |
#      {'weve','wed','well','our','ours'} |
#      {'isnt','wont','shant','d'})

#     original_stop_words = nlp.Defaults.stop_words

#     nlp.Defaults.stop_words -= original_stop_words
#     nlp.Defaults.stop_words |= my_stop_words

#     return nlp

# %%
# # # Load model
# # t1 = time.time()
# # # print('Loading models...')
# # # nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser']) # disable Named Entity Recognition for speed
# # # nlp.Defaults.stop_words = my_stop_words
# # nlp = load_spacy_model()
# # print('Models loaded in: {} mins'.format(round((time.time() - t1) / 60, 2)))

# # pipe(): Process texts as a stream, and yield Doc objects in order. This is usually more efficient than processing texts one-by-one.
# print('Cleaning up text...')
# t2 = time.time()
# #brief_cleaning = [re.sub("[^A-Za-z']+", ' ', str(row)).lower() for row in df_train['review']] # Doesn't do anything for this dataset (remove non alpha-numeric?)
# brief_cleaning = [re.sub("[^a-zA-Z ]", '', str(row)).lower() for row in df_train['review']] # Doesn't do anything for this dataset (remove non alpha-numeric?)
# next_cleaning = [re.sub(' +', ' ', str(row)).lower().lstrip(' ') for row in brief_cleaning] # Doesn't do anything for this dataset (remove non alpha-numeric?)
# final_text = [cleaning(doc.split(' ')) for doc in next_cleaning]



# # txt = [cleaning(doc) for doc in nlp.pipe(next_cleaning, batch_size=5000, n_process=-1)]
# # txt = [cleaning(doc.split(' ')) for doc in next_cleaning]


# print('Text cleaned in: {} mins'.format(round((time.time() - t2) / 60, 2)))
# Out:
# Models loaded in: 0.01 mins
# Cleaning up text...
# Text cleaned in: 0.0 mins

# %%
def clean_text(text_df):

    # pipe(): Process texts as a stream, and yield Doc objects in order. This is usually more efficient than processing texts one-by-one.
    print('Cleaning up text...')
    t1 = time.time()
    brief_cleaning = [re.sub("[^a-zA-Z ]", '', str(row)).lower() for row in text_df] # Doesn't do anything for this dataset (remove non alpha-numeric?)
    next_cleaning = [re.sub(' +', ' ', str(row)).lower().lstrip(' ') for row in brief_cleaning] # Remove multiple spaces
    final_text = [cleaning(doc.split(' ')) for doc in next_cleaning] # Remove stop words
    print('Text cleaned in: {} seconds'.format(round((time.time() - t1), 2)))

    return final_text



df_train['cleaned_text'] = clean_text(df_train['review']) 


# df_train['review']
df_train['cleaned_text']
# Out:
# Cleaning up text...
# Text cleaned in: 0.19 seconds
# 0        never personally thought writing review news a...
# 1        wish download images advance offline access li...
# 2        disabled health issues past couple years walk ...
# 3        good news source very two stars however really...
# 4        love listening economist audio edition particu...
#                                ...
# 11906              download more reviews tell base review
# 11907    great app big fan digestible news often week t...
# 11908    expect economist app very fluid responsive sig...
# 11909    happy economist taking finishability mantra cr...
# 11910                                                 None
# Name: cleaned_text, Length: 11911, dtype: object

# %%
sent = [row.split(' ') for row in df_train['cleaned_text'] if row is not None]
phrases = Phrases(sent, min_count=100)
df_train['final_text'] = phrases[df_train['cleaned_text']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-452e9ace32c7> in <module>
#       1 sent = [row.split(' ') for row in df_train['cleaned_text'] if row is not None]
#       2 phrases = Phrases(sent, min_count=100)
# ----> 3 df_train['final_text'] = phrases[df_train['cleaned_text']]
#
# ~/code/venv-python3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~/code/venv-python3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~/code/venv-python3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# -> 3899             value = sanitize_index(value, self.index)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
#
# ~/code/venv-python3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     750     if len(data) != len(index):
#     751         raise ValueError(
# --> 752             "Length of values "
#     753             f"({len(data)}) "
#     754             "does not match length of index "
#
# ValueError: Length of values (10645) does not match length of index (11911)

# %%
phrases[df_train['cleaned_text']]
# Out:
# ['never personally thought writing review news app year old college student generally skeptical news organizations taking class heavy usage economist articles why professor uses lesson plans factual multiple months contemplating not subscription finally pulled trigger app seamless minus features wish app like search option viewing history easier access friends articles wish half star less but stars enjoy content feel trust economist deliver news digestible palatable way enjoy able audibly listen articles understanding whats going world tired traditional american news companies like nbc fox cbs cnn washington post new york times try economist economist offers new level detail honesty factuality trust appreciate comes news reporting intend resubscribe more introductory subscription economist far understand not editorials opinion pieces offer thought news reporting deeper understanding current events',
#  'wish download images advance offline access like text audio like classic app least image streaming works better latest fixes huge data hog increased phone bill streaming cellular good option audio needs bit love needs setting sweet spot speed playback frequently starts playing wrong speed second skip should default button use car rather skip previous article narration sounds good remembers reading but only one article cant swipe one weekly refinding place clicking hamburger menu find sections clicking section often doesnt work times section headers rendered offscreen maybe switching landscape portrait mode',
#  'disabled health issues past couple years walk away cpa firm worked hard build but brain wants learn timeline economist app provides body needs days eyes struggle concentration tough pain airpods immerse learning economic world listening cant articles morning briefings perfect best gives things think ones lingering dinner time provide husband intelligent discuss mull feels thank',
#  'good news source very two stars however really expensive year unless complain threaten cancel not sure whats harder divorce cancelling news subscription cant easily app contact app look faqs log point find change subscription theres button says cancel subscription asked why given sales pitch writing based reason order forward cancellation required chat sales representative joins chat asked provide address why wanted cancel tried offering discount finally rep cancelled subscription entire process took minutes making hard cancel purpose people giving money bad business',
#  'love listening economist audio edition particular feature removed able organise audio playlist specific order world week business section finance select articles chosen among remaining sections able edition organise everything start stop listening confidence playlist remained order prioritised add audio playlist always ordered way economist world week leaders letters etc arrange playlist priority past yearsnow dont want bother economist track listened manually andor addingremoving playlist order listen tasks very unfortunate very appreciated feature customise order audio playlist available thank',
#  'let economist generally favorite news source however recently started listening audio version weekly content app player very glitchy failing load sections stopping unexpectedly losing place playing chapters selected audio quality not great preferred listening speed previously listened years weekly audio podcast apps handled audio cleaner way but links recently inaccessible maybe otherseconomist team love work audio interface thank',
#  'subscribed app itunes years sudden let log free membership economist schools library theres no way log app paying anyway frustrating let log paying tried clicking restore purchase itunes button gives error tried logging user password tells log itunes option tried deleting reinstalling app restarting phone work logged successfully website but doesnt same features app morning briefing primarily read morning zero negative stars possible currently cant use therefore provides negative utility time wasted trying log help resolve gladly update review stars',
#  'economist article economics topics generally high quality documented researched but middle conflict particular presenting facts actual events biased distorted cover israel crimes fir example reporting gaza article dont miss mention gaza ruled hamas israel ruled criminals article miss mention people gaza siege open prison imposed racist criminals ruling israel no human face economist reporting israel crimes economist consider oppressed eco pied same footing oppressor occupier conflict dishonest way report occupation generation nation destroyed killed prison dprcis basic human needs water racially eliminated deported home live managed survive refugees foreign lands',
#  'only recently subscribed economist initial impression favorable reporting more balanced accustomed financial times european publication read daily basis value european perspective american experiment evolving years sense desperation political left america want received davos try convince world abandoned principles revolution favor woke globalism truth americans never heard davos not interested globalist ideas president obama but hear american media',
#  'love economist but app suffers number issues logging paid subscription app demands subscribe popup bottom permanent link top logs frequently doesnt readily accept information log minor glitches no search function articles ordeal current issue find things interest extremely annoying contrary media app common practices clicking economist articles social media jump safari app takes seconds sometimes stuck safari pretends not subscriber demands subscribe before showing article paid good money overall layout app not extremely designed requires lot clicking allows one easily miss current articles less historical articles extremely difficult find graphics repetitive links links arent relevant not enough smooth seamless connections current historical articles',
#  'started reading economist years ago subscribed entire time interruption best conceived written edited newspaper english languagemost years carried hard copy world reading cover cover app no need carry hard copy admit inserts removed folded half long axis quite convenient getting new day nice upgrade weekly version hard copy days sometimes finish issue before one arrived economist withdrawal nice new minute taste day paces better',
#  'update developer responded said issue fixed release bumping stars fixedthe version app broke ability listen multiple audio articles phone pocket able pick article section auto play cellular data phone screen locked able load audio article shows went wrong error means end track unlock phone click retry button work',
#  'content reporting economist top notch usual however new ad system implemented simple touch ad force advertisement content open default browser set overly sensitive dont discriminate vs tap intent one thats simply scroll page created horrendous user experience constantly having switch app ungraciously redirected ad no interest recent issue began showing advertisements offerings assume compiling rigged conversion rates able pitch advertisers ad space showcasing external party ads',
#  'absolutely love redesign consolidation economist apps one only issue having ability access current edition friday morning centraltime usa reader shows new current edition sometimes takes upwards thirty minutes app properly register new edition tap takes last weeks release autodownload feature new audio doesnt work minor inconveniences no complaints great work reporting',
#  'sir new app simply excellent rewrite succeeded transforming app digital version weekly newspaper fledged source news catering not only times feel like reading indepth analysis issues linked articles end article allow wander read based topic linked articles previous issue inbuilt espresso function appreciated creating mode news consumption serve jumping off point reading domsome guyaustin',
#  'content fantastic review pertains new app primarily read articles listening excellent playlist features removed one able download only selected individual articles essential handsfree listeningthe only way listen individual articles open written article tap listen storythe playlist check off one left off one resume listening quick glance easily remove listenedto content',
#  'years user app predecessors same story great content buggy careless execution images fail download state kept always navigate left off audio features great paper but never work release marred crazy obvious bugs suggest seriously wrong qa customer service excels writing meaningless emails but otherwise worthlessbottom line app works more less but like toddler always work itthe ipad version useless moved responsive version years ago',
#  'chose use app promising features importantly ability articles read despite glitches feature worked ok yesterday lost check marks bottom articles read incredibly frustrating always working off issues try completely read past issues daily read read timerelevant updates new issues please fix change rating stars',
#  'economist content second fairly easy access welldesigned app particularly enjoy audio content only wish were slightly better options playback top list options play speeds ear best speed depending narrator save time additionally nice list total time issue total time remaining',
#  'app irritating issue notably ads sensitive touch frequently often two three times article launched app view wholly irrelevant website didnt ad let alone deliberately click scrolling article usually causes accidentally click ad launch web browser stupid irritating literally only app problem considering subscriber close two decades constant source disappointment',
#  'economist always great reporting exceptions five stars but new app needs designed better extremely annoying ads embedded article weekly earlier version app ads come opened magazine please format dont want facebook type ads magazine paying monthly subscription costs more netflix',
#  'economist grasp fundamentals bring world together spin daily basis great read listen trust content surely articles like immersion never ending learning going one suggestion try good things world macro geopolitical societal topics sometimes feel tone conglomerate articles tend negative realistic often glass half sure economist world way positive always influence followers ',
#  'access weeks edition mostly audio version jogging outdoors like easy way download audio version week wifi place end playlist start playing later far only way found approximate delete previous editions download new onealso listening app interrupts incoming phone call economist not automatically resume playing iphone',
#  'nb long big fan content economist review concerns only apps publication specifically ipadwhen economist recently think updated app moving paginated articles more trendy endlessly scrolling articles thought huge step wrong direction looked like cheap generic app bugs shoddy ui instance no way jump section one weeks issue bookmarking confusing miss pagination ipad call old fashioned but think best way present magazine articles but new app version vast improvement better look better ui easy bookmarks sync ipad iphone jump sections easily daily content addition weekly issues easy audio downloads said highly recommend app',
#  'old app gold standard magazine apps functionality perfect let immerse weeks magazine no distractions felt closer print version menu bar top always visible allowing click week want away scroll downread shouldnt refer weekthats section magazine confusing call magazine app never listen audio version why page dont why mess perfection use classic app but apparently doesnt recognize economist subscription frustrating',
#  'magazine certainly quite good but unfortunately version app released bookmarks not work properly iphone ipad bookmark articles phone day read night ipad but impossible device bookmarks customer support gave indications but not worked gave no helpi hope economist fix soon let know helpjonathan',
#  'economist remains one best sources news real shame lost way design perspective one least attractive news apps seen sure lot time money went developing new appwebsite but looks awful backgrounds different shades gray white dark mode worse weekly stories presented one long list no attempt design layout no thought gone use blank space margins visual coherence app whats worse old version appand website matterwere model clean uncluttered design',
#  'great content audio version presented but download audio not play offline iphone complains cannot find internet connection fix stars frankly wish publish audio way use feature rich robust podcast player rather use buggy app app great reading content however app stars',
#  'app hasnt super stable but mostly usable especially like streaming feature dont download issue app classic think thats update brought bugs fixed considering version number probably expected cant access previous editions iphone appreciate please fix soonupdate workaround previous editions delete app reinstall but really shouldnt like way',
#  'hello chose subscribe economist like content ability play audio weekly magazine articles like listen articles eat breakfast prepare coffee morning issues wish fixed suggestions things app better app doesnt reliably check mark articles played sometimes sometimes audio player menu crashes lot app signs tells subscribe subscribed signed itd nice espresso morning briefing play button listen audio love magazine far great content really hope issues addressed update really really like able listen articles thanks',
#  'like hit play bookmarked articles audio working list walking driving app missing way play audio bookmarked articles having hit play bookmarked article plays bookmarked article plays unrelated leaders article bit unexpected but love app happy subscription economist truly interesting news publication often helps understand world slightly different way',
#  'economist news outlet informed getting emotionally charged avoid verbose hyperbole sure avoid making grand assumptions based directional leanings allow reader determine discretion great variety topics sensational journalists harbored worldwide perfect combination brevity depth sensational outlet reading decade starting late high school not esoteric younger readers otherwisespecialized academics sign',
#  'dont always agree economists issues absolutely love reading print online one thing newspaper covers geographically thematically always engaging erudite way simply more involved world reading listening economists pieces more more loving daily online editiona highly useful efficient way remain caught fully aware thats happening',
#  'economist second incisive analysis news reporting hope tradition continues lifetimethe app simple designed absolutely rely clear thorough audio supplement love british accentsone annoying seemingly easy thing fix create audio playlist selecting items favorites playback always reverse order no ability reverse change order fixed',
#  'dont understand why audio player took step backward says audio downloaded but says cant connect internet cant play audio downloaded shouldnt need internet play unless playback functions app not phone wrong makes app unusable unless home internet driving good connectivity use audio road having revert slightly less clunky legacy app fix functional star added consolidating daily weekly content',
#  'subscribed economist off past years but often find stack unread magazines piling bedsince last subscription app more digestible daily read particular like included audio content often listen working commute find checking daily briefing days transition more daily focus',
#  'weekly issues downloaded including audio app not work offline images not load audio not play issue beginning not fixed huge oversight app leaders flights lot network times moreover old app fantastic way creating audio playlist play sequence offline thay far best way access audio removed legacy app doesnt work offline extremely sad poor showing digital economist',
#  'years ago picked economist dentist office started reading instantly forgot drilling noise audible inside waiting room havent app makes easier continue reading common sense tothepoint journalism theres little left kind reporting analyzing unbiased editing creative design advertising yet economist makes smarter meetings executives kinds industries economist little secret years',
#  'signed economist couple years ago saw bastion unbiased news major news outlets shamelessly promoting political party loved economist ruthlessly committed traditional values journalistic integrity unfortunately economist keeps slipping steadily left no means same category new york times cnn yet but no longer same category stratfor financial times decided cancel subscription economist not disagree opinions but cannot trust not opinionthank solid years good run',
#  'app better ios classic app ability playpause stories play series app open foreground missing feature enables use jump right audio story like listen one start entire section skip stories dont want listen heard additionally convenient able order sectionsstories playlist enabling user listen stories order prefer',
#  'long one favorite apps recently taken big step backwards feature released before readythe app continue reading notification return thats designed last article unfortunately smart finished last article essentially heres were reading last helpful more basic bug last screen were quote end morning briefing actually suggest continue reading brief sentencerelated articles gain check mark complete feature similarly flawed viewing article bookmarking scrolling add check markfwiw no interest continue reading feature worked correctly wish optionali sure contact support issues but havent seen addressed yet',
#  'economist app years travel work paper edition didnt always arrive before needed leave saw changed economist legacy downloaded app try today ipad mini hadnt connected hotel wifi went white screen economist logo switched legacy app reading weekly magazine downloaded days ago havent yet found download option offline usage new app',
#  'love economists content death but app not justice number minor flaws thoughtless omissions render app unusable one primary purposes itlistening audio edition long walk unlike prior economist app no way cull together playlist audio articles enjoyed feature let set playlist roughly long walk nice able skip articles not interested read print second more importantly design bug audio turns off soon leave app darken phone screen words leave audio running phone pocket audio stop completely soon phone autolocks minute thats absurd should fixed immediately economist remains best source news analysis planet but audio feature not snuff',
#  'favorite thing updated version app prompts read more broadly economists magazine past issues rarely time read past realize missed appreciate app gives option view todays pick selection articles actual newspaper table contents espresso content one place',
#  'great app resubscribed economist year genuinely surprised far come app better very user friendly favorite actually listen articles not generated texttospeech software thank reporting news not abundance opinionated articles happy finally return unbiased factual reporting highly recommend',
#  'new york times think great job covering u s major world events however want better understanding happening regions world economist thoughtful way covers stories issues probably not read era poor analysis writing pervasive economist excellent standards known',
#  'tends crash lot updating scrolling hangs awhile starting annoying going old appi find crashes gotten better but scrolling not impossible time start app spend little time getting like little pebble shoe constant irritantmany times scrolling accidentally open image finger rested sure button appears close should visible time',
#  'content great no doubt content great trust content great why cancelation process difficult prefer apps subscription cancelation easy accessible app least website subscription process says cancelation anytime but cant cancel app website answer questions told call order cancel wait talk representative only tries subscribe omg seriously outdated strategy makes new generation not wanting subscribe',
#  'finally broke subscribed covid coverage didnt cringe economist not disappoint finally news source competently portrays quantitative figures trends clearly hired excellent analytics staff work journalists why app instead think app ways terms ux functionality accountlogon issues hope economist dial support tech teams treating issues priority',
#  'like overall design combo expresso edition but main things noticed issues button play audio embedded article makes easy accidentally click start audio accidentally annoying new app not regularly remember left off weekly edition like previous app causing repeat scrolling find last article',
#  'magazine subscription always saturdays greet mailman comes highlight weekend cant find articles depth written focuses world events more unbiased viewpoint periodicals usually read magazine cover cover hours love charts graphs accompany articles thank amazing writing intellectual writers',
#  'subscriber wonderful magazine past yearsand only gets better age why example listen week contents entire magazine audio download thats wonderfully read jog walk little dog enriching mind best written articles politics economics business finance appreciate magazines classically liberal open progressive free enterprise viewpoint',
#  'use mostly stream audio two bugs sometimes doesnt remember left off last time come resume stream plays heard big sometimes stops playing one article play controls not very reactive content great upgrade stars bugs fixed',
#  'not subscribe itunes only able interface app single device subscribed apple doesnt offer login criteria website available try access mobile device ask login criteria talk apple customer service peruse economist website no help try call economist tell talk apple',
#  'legacy app forced stop months ago clunky but better mostly use audio version not work unless good internet connection despite having downloaded audio no audio contents list allowing choose article freely frequently crashes freezes love quality articles but audio app terrible',
#  'great visual improvement old app but dont like changes listening sections button media player only shows sections cannot click teal sections button hovers bottom right allow click sections but scrolls section instead playing audio think fine but confusingthe ui pretty buggy example teal sections button floating halfway screen no reason went bottom right scrolled bitin short want configurable playlist like old version better want ui bugs fixed buggier expect company largeyou great looking app but think need polish user experience happily change rating saw improvements',
#  'read economist years but version app magazine amazing tool advantage content produced magazine threads together weekly issues daily briefings older articles same topic should want read more graphically easy eyes provides photo journalism magazine wellin short love app',
#  'subscriber reader economist long time find consistent source solid information world financial developments addition larger trends social economic events occurring planet provides refreshing viewpoint given fake news conspiracy theories circulating social media questionable news sourceskeep good reportingbill tichy',
#  'works wonderfully last years listen crowded train look kalmost important unlike harvard business review economist app iphone not need tablet access review app content generally unbiased great sometimes sense writers bias gets little strong criticizing centrists often right wing lunatics stars content',
#  'worth paying least one reliable source news one use stays mainly mudslinging partisan political spats following stories providing detailed analyses opinion pieces particularly like morning briefing gives summaries top stories day highlights quickly stories audio option',
#  'baffling outstanding news organization hire professional readers create audio edition difficult listen previous version app effortless create playlist section individual article app manually play one article manually play article etc whos idea thisand please dont tell legacy app allows playlist creation makes playlist creation more difficult confusing before fix old version please',
#  'love content unfortunately purchase subscription app cant access account online viceaversa customer service informed working integrating app digital platform but offered no current solution positive note customer service highly responsive easy work greatly appreciated',
#  'main frustration economist apps times latest available app functionality remember page left reading but time time economist releases supposedly better app gains functionality but loses ability return page left happening version economist hopefully developers realize critical functionality magazine app please fix asap very happy increase rating stars continue prior version',
#  'cancelling nyt subscription intrusive adverts thoroughly enjoyed reading economist iphone however frustrated lack ability define words app presume effort prevent users copyingpasting articles app but missing feature nonetheless shouldnt hard add proprietary highlight allows define but not copy text',
#  'liked previous version think new version better end but new version bugs open app not remember page reading switch new article push audio button audio keeps playing previous article',
#  'love economist content lot great recommendations but app frequently chokes start morning no matter long wait screen locked kill relaunch app always works normally never problems initial launch day kill relaunch app more mornings',
#  'reading publication years enjoying audio version nearly long app helps enjoy greater speed read simultaneously subscriber app glad decided allow listen app threatened prevent',
#  'app got better previous versions particularly saved section allows list articles different editions however reading weekly prints got more difficult subtitles one click article know given time titles puns please bring subtitles tks',
#  'theres no better time highlight poor journalism overly biased thankful economist able remain mostly objective provide high quality coverage written articles important events stories shaping world live today thank remaining consistent true global journalism',
#  'read one device like ipad home dont nice little check marks devices like phone line grocery store cant scroll checks disappearsmall complaint literally only one far but havent app long',
#  'marked app legacy mean phasing main appbut one one major flaw absence playlist old legacy app long drives work playlist crucial pick articles want before starting car cant anymore manually switching articles driving not safe waste time listen article order decide want not old playlist system not broken why rid itplease bring thanks',
#  'app sleek welldesigned only reason writing review ask developers fix access images articles scrolling article accidentally click graph comic switch economist image header opening images should less glitchy overall not difficult avoid opening reading article wish graphics were higher quality',
#  'new app disappointing everything takes forever load sometimes simply doesnt very latest apple ipad pro doesnt work outset everything loads incredibly slowly not right latest weekly issue simply load restarted app twice very frustrating',
#  'thing love app articles paired voice recording great way read economist article tends dense long having somebody read makes more accessible enjoyable really love economist articles farreaching understanding whats happening world contrast myopic news daily newspaper',
#  'excellent app fitting outstanding journalism clear design dark mode adjustable text size really love optional new audio autodownload articles fully voiced amazing commutesmy only complaint bookmarks not searchable sometimes looking love able type search term find know bookmarkedoverall excellent app',
#  'wonderful reading experience great features like bookmarks copy paste background content syncbut battery drain app egregious lose battery mins spent reading minimal brightness preposterous suspect background mischief going problem not persist airplane mode sure read airplane mode plane but cant afford disable phone check news overall promising stuff but battery drain resolved stuck two stars',
#  'economists app very nice app gives impression hold real magazine choose read listen article surfing among sections easy only downsize frequent log requirement dont use app days app logs need log doesnt option save log details needs improvement',
#  'economist only publication found delivers truly analytical researched thoughtful perspective everything covers covers everything delivers platforms love choice listening reading articles short daily summaries subscribe variety delivery options use truly five star news organization',
#  'economist great news content unfortunately treat app like complete afterthought nonprint subscribers like secondclass citizens months updated inevitably one cannot log numerous calls emails reinstalls undertaken looks like away email support call phone tree abundant free time magazine charges substantial subscription price one think spend bucks pounds hire reputable app developer',
#  'time use updated economist app burns ipad battery pace no app ipad actually heats point feel uncomfortable happen only updated version economist app not appear allow download current edition magazine ipad legacy app found no power camping unable read economist app legacy app allows download current edition not worry access internet not',
#  'like app lot better economist classic app only improvement like iphone users scrolling text gets time upper left corner same network info right top corneras read like check time scroll find blank space able check time',
#  'news economist fantastic always however app getting worse worse near tell nonfunctional not active internet connection despite option downloading entire issues top active connection time changes story error comes saying went wrong requiring action listeners before story plays bad often switch recorded book frustration',
#  'middle reading article text need reply switch app write text come economist expect left off article but not home screen navigating way article doesnt bring were top app thats ostensibly reading glaring problem',
#  'obviously economist valuable content comment subscribing app were poor but app far best newsmagazine app encountered news junkie encountered plentythe economist but kind thought usability clarity goes writing charts app design shows',
#  'one hand economist app why smartphone three issues drive nuts no way bookmark articles audio playback interface thats pretty only time want bookmark freezes regularly audio playback loads new issue not quite finished readinglistening previous week',
#  'one worst updates app really bad ones past biggest issue download entire audio version able download audio select articles not update signs off updates',
#  'use classic application major drag application however everything longing related articles bottom wish extend current newspaper easy audiostreaming access cleaner layout wishlist please add search functionality thank appreciated',
#  'economist publication top notch rating five stars like listen audio version app often works wonderfully unfortunately often inexplicable stops articles dont mean pauses but stops altogether really detracts value able listen activity',
#  'always love quality content economist provides think things changed like ease navigating one storyedition universal search specific articles dont think app intuitive younger generations but assume readership skews older folks anyway works overall definitely works articles always top notch',
#  'consistent quality research dedicated writer talent feel informed knowledgible world local news scene tv leaves substaintial void analysis thankfully concerned citizens rely economist continue bring forth quality journalism enrich lives discourse peers friends family thanks reading bbe',
#  'prefer reading hard copy but collecting weekly issues wasteful reading experience ipad wonderful page dimensions typeset navigating issues articles read soon issue goes live save favorite articles list pull fir future reference',
#  'enjoy economist app deep research thoughtful point view able discern view point actual actions going like morning briefing coupled podcasts layout functionality easy use fluid thank economist continued research reporting clarity articulation',
#  'institution stories economist app remains shockingly poorthe audio portion strong competitor podcasts unusable audio stop midstory revert beginning trying scrub point queue multiple stories hampered poor ui choices working tech nightmaresi want app stars but really needs fixed',
#  'husband received subscription economist wedding present devoted readers enjoy excellent topics indepth research unbiased positions awesome writing not mention wit amusing characterizations bonus magazine addresses economic status global news events definitely fans',
#  'love economist but app terrible no longer list articles stream audio play section written article play incomprehensible update streaming audio way more difficult especially people listening commutingwalking buggy maneuverability cant press button hidden display sometimes audio stops man hate app probably not worth keeping electronic subscription',
#  'paying subscription apple not digital access economist website not clear signing no way link apple subscription economist account economist should fix clear',
#  'consistently best source thorough thoughtful coverage events world writing exceptional closing sentence article story enjoy reading economist years advice friend only wish introduced years before',
#  'app overall organized great able browse weekly magazine same format printed one only complaints occasional glitches getting logged sometimes occasional crash fixed starsthat said quality content economist fantastic magazine',
#  'hard copy online version access app iphone ipad read hard copy should able mark section doneread not read app thanks',
#  'particularly love morning briefingsconcise summary significant updates world lets quick overview want dig deeper day audio main stories added bonus want listen things love economist',
#  'love content subscribed decade but economists apps abysmally implemented economist app inexplicably reverted featureless androidedition clone last year app basic functions dont work problems fixed features broken postupdate recently running audio edition heats phone tremendouslyit easily felt silicon case no app use felt like perpetual betatest',
#  'read recommended package friends family no notice app turned unnavigable going tuen everything upsidedown users notice b option god imbeciles',
#  'like happens months app but yet latest update broke audio playback downloaded content need network connection story story app loses place stories restarts',
#  'month trial subscription requested cancel later changed app economist refused cancel subscription deep junk mailbox asked call confirm cancelation realized years later charging time double charging paid app politely asked refund refused reimburse subscriptions hit cancel cancel but economist actively manipulatively obstructive canceling resulting stealing careful trial subscription total scam',
#  'outside fantastic reading material economists app really makes stand alone informs left off articles read estimated time read articles nice reading experience doesnt feel cumbersome overly dense definitely recommend',
#  'economist worth premium price articles poignant subject matter right alley enjoy short daily news updates morning briefing only gripe app updated frequently update presents new bugs affect app experience but least strong app support',
#  'economist one best news sources unfortunately app terrible way consume fails retain position time shift away app drop home page force scroll were second layout reasonable ipad flows text one column not margins makes sense phone but way wide hard read tablet vs columns layout narrower view very disappointed',
#  'usually forget section title article want read only vaguely remember keywords artical check possible article one one annoyingly timeconsuming fallible please add search feature one issue classic version possible global search appreciated',
#  'recently resubscribed taking break trying cheaper options month came no one better job getting speed world events app experience improved dramatically last months',
#  'purchasing itunes prompted input log credentials clearly states log economist device attempt log says not subscription tried calling digital support team claims exact opposite itunes purchases cannot log computers browser not sure correct but frustrating not renewing subscription not resolved renewal date',
#  'subscribed economist years always incredible job not beholden interests particular political narrative objectivity wasnt standard but calling card thats changed last year two like media today no longer beholden objectivity but instead biased onesided narratives modus operandi whos trusted magazine years sad fall intersectionalist politics not renewing subscription newspaper',
#  'love layout curation best worldsthe website weekly edition app only wish downloaded audio autodelete feature like weekly edition app should autodelete two weeks month previous editions sure deleted downloads',
#  'hello like recommend small improvement app possible allow quote day shared fb twitter text etc currently quote only directly shared espresso app like same function economist app please let know clarify thank considering',
#  'looking more newspaper time makes happy but use ipad like laptop screen rotation vitalok fast response missing opened today screen rotated perfectly exactly want app version',
#  'clearly reason publication years quality research writing breath depth weekly articles wellinformed important events world busy daily basis',
#  'new update finally puts economist app frankly should always digital offerings available single locationand mirrors approach taken website finding splendid app more good work',
#  'world entertainment confined tempting click bait myriad available devices economist fails disappointits interesting left leaning articles inject life mundane daytoday trodding pandemic lockdownstheir new audio feature brings memories german nanny reading time before bedtimea valuable edition ones treasure trove apps',
#  'start playing weeks new issues audio plays previous weeks audio insteadalso nice possible play audio bookmarked stories continuation instead having taking phone pocket',
#  'beware spent months economist forth days reply trying figure why open iphone but not ipad finally learned today only view one device not advertised purchased app fact purchased iphone traveling but intended read more om ipad very frustrated took long figure b not advertised obvious cancelling subscription',
#  'app evolved favorably ways glitches audio offerings improved substantially interface written offerings appealing easy navigate top rate news source top rate platform',
#  'love idea podcasts started but bit clumsy use not nearly easy online readingits working better got worked but having challenges getting run continuously iphone recently happened aberration',
#  'love economist subscriptions not cheap but quality journalism tremendous value however completely unable use app login not work contacted support told download legacy app able log app no problem however downloads issues doesnt uptodate news big bummer considering price availability think app exceptional instead garbage',
#  'app content good advertisements placed right individual scroll article causing leave appanother downside purchasing annual subscription weeks ago print digital print magazines not delivered trying read off app ads placed articles very frustrating paying subscriber wish way disable',
#  'iphone plus model ios minutes starting app phone heats battery drops quickly dont dislike app hope review attention issueupdate problem hasnt solved update like problem solved claimed',
#  'longtime economist reader greatly values content struggle regularly app ipad rarely loads story click daily emails accidentally clicking picture sends off article never unless restart reading process news source ditched long ago',
#  'doesnt memory feature economists iphone app remembers listened last time but doesnt bring left off reading definitely improve said very decent app one easily tell lots resources invested',
#  'app polished found way read issues current issue not able access read prior issues extremely disappointing please bring rate two stars',
#  'text selection lack ability look words search web share quotes quicklywould great playlist audio auto play audio bookmarked articles use playlist',
#  'app designed making easy read headlines articles economist course exceptional newspaper doesnt fall binary trap reporting informative indepth always perceptive read business global politics one favorite topics reporting business sports',
#  'app horribly disappointingcontent not compromised expected quality economisthowever unfortunate app design especially audio makes content difficult enjoyseriously why offer audio akin listening cassette tape ',
#  'grateful unbiased reporting hard find days politics bring emotions edge completely enjoy able news read driving work able wisely spending drive time',
#  'economist provides invaluable perspective global events subscriber past years gaining access digitally possible only recently appreciate able read wayat convenience time',
#  'app good minor bugs popping good solution app bug reporting settings tab add bug report screen lets users submit screenshotscomments bug otherwise googling trying figure submit bug giving letting',
#  'not except new version crashes startup iphone reinstalling doesnt solve problem hope version working off line viewing plane',
#  'years taking paper edition decided add digital version glad economist fingertips point day economist demonstrates balanced approach reporting news written accessible brilliant english appreciate depth coverage age soundbites',
#  'having introduced economist reading economics classes university come rely economist relatively unbiased politics obviously economics dont rely pandering peoples fears biases clickscouldnt recommend magazine relatively simple flawless app',
#  'find reading economist refreshing engaging helps mind interact new ideas people world really appreciate humor intelligence articles enjoy learning new things never read before new takes issues familiar',
#  'love economist charts better reader magnify wear magnifying readers read economist iphone elements charts small text sizes colors illegible rendered small screen',
#  'economist app ipad amazing lightning fast incredibly easy use ability adjust brightness increase font size godsend less perfect eyesight why cling paper edition long life changing development',
#  'anytime open article weekly offline airplane prompts log logged old app allowed download issue download audioalso espresso not allow navigate previous days espresso issue nice feature original espresso app otherwise good ui',
#  'love one listen audio version article switch seamlessly text voice downloading bookmarking work no login problems far suggestions add speed option audio suggestions submission feature app',
#  'economist public broadcasting nyt receive informative input depth analysis invaluable lost iti receive economist printed line form weekly magazine great but difficult read type quite small',
#  'audio restarts goes beginning article listening car home very annoying thing scroll forth place left off please fees fix bug',
#  'great app unfortunately no way tell issues audio downloaded completely result leave house thinking new issue economist iphone alas playback stops rather soon plane driving wifi please return indicator showing audio downloaded download complete',
#  'great writing important topical info importantly app understands likely offers great functionality audio version stories makes multitasking possible only complaint ability add stories playlist nice improvement',
#  'app usually doesnt work s max tried redownloading times sent message requesting account canceled canceled account phone bought subscription less rd party subscription not canceled days later articles opinionated very left leaning not ideal want learn whats going having muddle reporternews organizations political opinions',
#  'listening economist app news balanced comes iterative improvements quality user experience app customer years come',
#  'really annoying facebook really interesting economist article click itll app takes web browser says not logged cant open article app cant search articles only ones were posted week',
#  'great audio daily briefing morning time busy multitasking love hear commute work need better voiceover audio briefings look podcasts inspiration current one dull boring takes energy focused listen thing',
#  'signed paid economist digital subscription however let access articles says need subscribe try subscribe states subscription aware charged app cannot access',
#  'why play audio playlist iphone coax play article time only place hear audio best magazine isi guess talking downloaded audio',
#  'previous issues wall no cover art downloads kal cartoon no article illustrations appear happily economist article adverts rendering perfectly please fix basics experience great old app new app very buggy',
#  'audio randomly start playing paused frequently happens middle phone call requiring unlock phone open app manually stop audio problem year app why ads middle articles economist expensive showing lowquality web ads bought subscription',
#  'older app ran fine but newer one easier use better functionality unfortunately makes phone super hot randomly crashes minutes fresh install doesnt fix eitherim iphone xs think able work latest version but actively gotten worse past months no signs getting better unacceptable',
#  'web page news reading app lets know far progressed page little scroller right hand app doesent night mode makes weird dont know long story causes abandon stories scrolling long losing place process not hard fix',
#  'theres like old age whet ones appetite accurate news coverage fluff appreciate economist very longstanding subscription magazine yearsbarely read work schedule absorb allday thank economist',
#  'shouldve received paper copy week but arrived shipment arrive two weeks later ridiculous please sure shipment arrive right time right place',
#  'economist riding crest international affairs refreshing more informed perspective minimize incumbent distortion goes trade more balanced nonetheless increasingly wider scope were covered include events albeit seemingly trivial but informed insight significantly impact global humanity positive negative craft skilled unbiased penmanship',
#  'unlike news app never ending rabbit hole news economist gives stories day shows caught great way worlds news getting lost never ending news cycle love economist love app more',
#  'really enjoy reading economist however quite annoying ipad version lack support splitview always want open dictionarybrowserwikipedia small window reference immediately reported bug one year ago feedback improvement no basic ipad keyboard shortcut like space button scrolling therefore sorry but one star time app updated change five stars',
# ...
#  'hard find trustworthy source news challenging but generally balanced opinions should better agree not suggestions read economist staying properly informed before mind thanks',
#  'new version app not intuitive starts dialogue box dismiss problem not clear assume app crashed downloading latest magazine happens background but click previous editions lastly based uk why dies start off news content awesome app better feel but not perfect',
#  'world increasingly short attention span everything indepth analysis researched writing publication treasure sometimes dont understand often dont read weekly issue but gradually becoming better informed interested concerned going corners globe',
#  'update better audio improved easier understand navigate app cueing stories listen makes morning commute more interesting',
#  'content super app intuitive pleasure look couple small issues giving stars feature displays check mark articles finnished read economist more one device moment check mark only displayed device read article great feature synced account read tablet checkmarks appear phone second audio player breaks occasionaly makes app unresponsive crashes',
#  'podcasts daily briefings economist app very user friendly reads articles aloud indicates reading time article splits content daily weekly saved sections really enjoying subscription',
#  'app fine reading but audio mode fundamentally broken point close unusable bugs include download audio not download audio selected audio play unless internet connection present moving article playing speed one selected eg audio continue playing but controls disappear audio controls dont match audio playing not ie play button shows pause despite audio not playing moving article skip end story stop overall extremely poor compared quality journalism',
#  'new menu button bottom right jump section great addition huge improvement text justified however option text left aligned really awkward read',
#  'love new app great everything one place however audio content not easy access navigate please old app select specific articles listen',
#  'world apart previous versions content excellent audio no publication touch pay extra apple watch companion app allowed run whilst listening economist audio playlist having bring phone',
#  'swapped legacy version quite like new designone thing really annoying article sections different order legacy app print copy newspaper uk pleases changed uk order articles ie britain section leaders least option order goes assume order version newspaper',
#  'app condenses print version very succinct way able hear articles audio approximate time reading duration excellent features orders content cleverly easy digest only criticism nav sometimes confusing not intuitive however minor fault',
#  'great app easy use able download weeks audio listen convenience not connected travelling able look previous editions articles easy send links articles friends thank',
#  'love economist read week why cant app works never know big improvement previous apps but honestly needs reworking simple things like audio play option disappearing not able reactivate one option play',
#  'try read articles logs try restore purchases error message making impossible tried contacting number times but no avail disappointing',
#  'audio autodownload ios controls non standard unusable come economist consumption tube internet impossible programme audio consumption compelling content dont drop ballthe apple store ratings wildly misleading',
#  'open app tube stops article reading often spontaneous changed difficult find old article disappeared v annoying',
#  'new daily picks shortread section greathowever use wifi ipad want able read train work old app download home know downloaded new app gives no indication downloaded not download images advance detracts experience please fix',
#  'espresso wellnamed quick stimulating pickup days essentials summaries chosen saturdays format makes interesting change concluding thought prompts wideranging discussions morning tea more mistakes newspaper but corrected promptly thank',
#  'recent new version great reading finding content easy very intuitivei subscribed economist more years contents great readings personal knowledgei definitely recommend',
#  'great app keeping date going world like design structure app performant transitions screens smooth fast save article audios listen later more convenient highly recommended',
#  'little time reading material not directly related work but needing stay date developments world large head risk global asset manager economists audio edition boonthank',
#  'new economist app basically rubbish pay paper digital fact digital version follows completely different order print version really annoying gone legacy edition recommend same people option choose edition wanted british asia etc fine however economist decided were american not very internationalist',
#  'quite happy app easy use option listen articles handy feature liked more functions options example search function allow access older articles',
#  'new version economist app extremely poor week week try read current edition only refused previous weeks edition open instead paying digital subscription cant read latest edition',
#  'like use app easy browse magazine quickly articles interested previous magazines',
#  'app awful provides terrible user experience struggles download editions hard navigatethe audio features pretty unusable takes repeated attempts download audio often fails work often looks like worked only switch airplane mode find hasnt no longer option download articles wish listen probably partly blame download speedeven downloaded audio menu hard navigateall app significant step previous version come economist lose loyal customer',
#  'previous version worked issues new app audio function works badly takes longer access not allow solid access line not audio articles system stopping working getting stuck trying weeks no improvement very disappointing',
#  'content great but new app awful crashes frequently constant scroll lagstickiness header bar flicks annoyingly reading pane no ability change article order reflect region like not switching classic app whilst not perfect issues allows read editions world simply less frustrating way consume content',
#  'switched new app old pair espresso economist one not render iphonex words missed off page settings page cant words bit mess given target market',
#  'app performing relatively last two upgrades led constant crashing ipad pro performed typical remedies restarted app restarted ipad reinstalled app etc but worked ultra frustrated',
#  'brilliant journalism but poor user experience accidentally click advertisements app article read truly necessary bombard paying users ads more intuitive way users dont accidentally click whilst scrolling',
#  'iphone battery usually last days except read economist app two hours app running background drained battery',
#  'navigation easier but articles excellent quality economist always good value always thought provoking offers insight range different things',
#  'previous versions pick articles download audio playlist playing current version download everything takes storage no playlist instead play article manually stupid annoying why update app going worse inferior earlier version',
#  'app crashing continuously especially sections audio quite wonderful but worthless cant use why download option cant listen offlinevery jerky experience far',
#  'bugbear app easy accidentally touch advertisements reading knocking one app safari look website no interest',
#  'love app love print edition but itunes subscription keeps having restored restore frustrating spend age trying articles lose time explore publications',
#  'years subscribed range news feeds guardian week times etc but honestly package offered economist offers widest coverage best value economist ',
#  'afraid economist app no longer opens started today before downloading latest version continued uninstalling downloading newest version',
#  'economist app excellent way keeping abreast developments world day simple easy digest yet informative items range topics like access weekly edition plus selected longer form articles topical issues',
#  'probably stupid however try cannot find download weekly economist app end having read iphoneotherwise great',
#  'app crashing snd not open despite uninstall ans install multiple times addition shutting ipad digital subscriber big problem please fix priority',
#  'simple structure but not content puts digital offering news media space shame exception new york times clear relevant',
#  'intelligently written magazine however dont think layout great navigating finding things easy figure one way suggest little cue guardian maybemy opinion not passing judgement',
#  'performance improvements one favourite apps really great contextualised news app automatically downloads articles daily fuss super great viewing commute signal thanks',
#  'new app far less user friendly podcast fans old edition download individual sections articles one podcast download thing yes upgrade makes things worse not better customer economist pretty critical corporates things wrong pity doesnt look harder offering',
#  'very good app love ability listen articles very handy crowded morning commute main issue left hand text sometimes disappears restart app otherwise good',
#  'great weekly daily economist one place wish audio version less laggy always worked minor complaint normally good app',
#  'ipad version low resolution version iphone one result everything big reads poorly handles changing screen orientation badly old version app menu great meant article right size',
#  'like new app enjoy reading economist tooone problem new app large sensitive adverts impossible not click readingscrolling really irritating expensive advertiser surely pays clicks error',
#  'written researched content but variety formats making information easier access digest',
#  'great app simple use looks tidy ability bookmark articles handy sometimes app theme doesnt change phone but thats only gripe',
#  'app open previously audio player problems time always randomly stops playing says unknown error occurred rectified pressing ok however involves unlocking phone pressing restarting point loses place really like content but honestly testing app bug ridden years ago',
#  'good but not great useful better feed articles better method queuing audio car journeys etc method syncing articles read multiple devices read iphone ipad off same account',
#  'very look forward reading economist week app article reading status synchronising different devices search function',
#  'use app audio playback fine long dont leave more hours stopping one article starting likely taken very start recent edition not downloaded',
#  'three modifications new features really appreciate more text sizes smallest text size small size quite jump large opinion opinion text size iphone careful balence having enough words perline users not forced constantly scroll text not small comfortable landscape reading same reasons order audio article should match order text articles should case regardless regional seeings apple carplay support far feature hopeful',
#  'good app but one niggle split time iphone ipad find lack basic synchronisation apps terms bookmarks read ticks etc frustrating pretty basic functionality app days',
#  'v good far better ft app only things improve stop images popping open easily hard dismiss enable app open last place reading overall great experience',
#  'economist clearly important impressive publication but miss formatting print edition rather stars superficial grumble admit recall earlier versions digital apps retained formatting cant believe reincorporating style sheets technically prohibitive',
#  'last week app frustrating issue scrolling maybe seconds screen time app gets extremely slow sticky drains battery like problem only fixed close app completely reopen rather annoying fix very appreciated',
#  'think decent search engine utilised finding historic articles but not case cant past one significant flaw offer impartial review soon new edition comes history eliminated ability cross reference very disappointing',
#  'app good quick keeps track reading offers audio versions however adding adverts inside article expect freemium product tabloid not product paying sad addition damaged otherwise perfect app product',
#  'updated new app stay open crashes repeatedly legacy apps access news disappointed',
#  'app updated allow barkmarked read articles visible devices far easier read devices',
#  'economists news good quality like articles based data fairly balanced dont try force opinions like lot papers app simple navigate keeps coming more',
#  'app amazing new update app freezes time please change scroll whilst listening audio',
#  'content obviously brilliant but looking specific article app really clunky navigate not able look old articles feels like dont time listen article right itll lost soon opposite ondemand service',
#  'app improved but listen articles briefing always stops mins start end skipping remainder moving article annoying but better previous versions',
#  'please fix urgently app iphone ipad stopped working latest update july crashes immediately opening',
#  'cannot run ipad pro freezes tried uninstalling reinstalling multiple times gone economist classic app',
#  'love variety content available economist app but very slow irksome listening podcasts eg changing frustrating load slowly app takes lot battery life despite having turn volume hear like app updated run little smoother less draw battery like option receive more push notifications articles sum good app but improvements',
#  'overall app fine but playback control bluetooth headsets doesnt workaudio downloading buggy slow app doesnt deal interruptions network connectivity',
#  'bought year subscription app turned itunes subscription cant crn number accesswhen called economist help line were unhelpful usual',
#  'unable activate subscription economist subscription team blame solely rd party vendor ie apple app developers fault methods registration requires crn want pull socks better app speak sub team provide better support not offer option subscribe app cant arsed support itthe economist fine',
#  'endlessly tells need log restore purchase itunes subscription days unusable',
#  'terrible stability constantly crashes cannot more star completely unusable',
#  'love app beautiful love audio integration but day need log please stay logged enable face really dont want input credentials morning',
#  'aside superb content tactical touches required not continually launching ads safari scrolling honest found surprising paying quite bit subscribe',
#  'good app however reading weekly tab ipad marks articles read doesnt sync iphone app useful homeit syncing saved articles devices',
#  'interesting articles topical discussions great find news not covid only comment negative app more user friendly sometimes difficult navigate find articles marti',
#  'app quite difficult navigate listening article no clue find should want read listen againtoday ipad text halfon screen hold screen sliding read article',
#  'worth subscription app podcasts magazine favourite outlet politics economics arts current affairs only problem addictive reading articles cant',
#  'try run app crashes immediately displaying splash screen worked fine before restarting phone reinstalling app not difference not good enough',
#  'great audios auto download app loaded enjoyed traveling tube reception',
#  'love economist keeps date wish summary version weekly publication not feel missing dont time read articles want read like ml applied personalise reading list suggestions',
#  'mentioned app far good content excellent economist app one classic version three years always bugs apps frustrating use old bugs were fixed new ones were added point cant believe incompetence sort social experiment',
#  ...]

# %%
phrases[df_train['cleaned_text']][8]
# Out:
# 'only recently subscribed economist initial impression favorable reporting more balanced accustomed financial times european publication read daily basis value european perspective american experiment evolving years sense desperation political left america want received davos try convince world abandoned principles revolution favor woke globalism truth americans never heard davos not interested globalist ideas president obama but hear american media'

# %%
df_train['cleaned_text'].values[3]
# Out:
# 'good news source very two stars however really expensive year unless complain threaten cancel not sure whats harder divorce cancelling news subscription cant easily app contact app look faqs log point find change subscription theres button says cancel subscription asked why given sales pitch writing based reason order forward cancellation required chat sales representative joins chat asked provide address why wanted cancel tried offering discount finally rep cancelled subscription entire process took minutes making hard cancel purpose people giving money bad business'

# %%
from collections import defaultdict
word_freq = defaultdict(int)
for sent in df_train['cleaned_text']:
    if sent is not None:
        for i in sent.split(' '):
            word_freq[i] += 1

sorted(word_freq, key=word_freq.get, reverse=True)[:100]
# Out:
# ['app',
#  'news',
#  'great',
#  'economist',
#  'but',
#  'read',
#  'day',
#  'morning',
#  'not',
#  'articles',
#  'good',
#  'world',
#  'daily',
#  'content',
#  'very',
#  'way',
#  'audio',
#  'espresso',
#  'like',
#  'more',
#  'love',
#  'start',
#  'time',
#  'quick',
#  'one',
#  'subscription',
#  'reading',
#  'no',
#  'excellent',
#  'easy',
#  'stories',
#  'use',
#  'article',
#  'only',
#  'concise',
#  'short',
#  'version',
#  'nice',
#  'new',
#  'really',
#  'update',
#  'perfect',
#  'summary',
#  'work',
#  'events',
#  'dont',
#  'best',
#  'always',
#  'magazine',
#  'brief',
#  'better',
#  'issues',
#  'doesnt',
#  'edition',
#  'days',
#  'informative',
#  'please',
#  'cant',
#  'information',
#  'works',
#  'need',
#  'global',
#  'weekly',
#  'download',
#  'important',
#  'current',
#  'quality',
#  'written',
#  'source',
#  'ads',
#  'want',
#  'coffee',
#  'why',
#  'find',
#  'going',
#  'issue',
#  'enjoy',
#  'access',
#  'interesting',
#  'listen',
#  'simple',
#  'little',
#  'fix',
#  'minutes',
#  'useful',
#  'open',
#  'should',
#  'gives',
#  'apps',
#  'before',
#  'free',
#  'right',
#  'top',
#  'however',
#  'point',
#  'informed',
#  'thing',
#  'often',
#  'briefing',
#  'whats']

# %%
df_train['cleaned_text'][0]
# Out:
# 'never personally thought writing review news app year old college student generally skeptical news organizations taking class heavy usage economist articles why professor uses lesson plans factual multiple months contemplating not subscription finally pulled trigger app seamless minus features wish app like search option viewing history easier access friends articles wish half star less but stars enjoy content feel trust economist deliver news digestible palatable way enjoy able audibly listen articles understanding whats going world tired traditional american news companies like nbc fox cbs cnn washington post new york times try economist economist offers new level detail honesty factuality trust appreciate comes news reporting intend resubscribe more introductory subscription economist far understand not editorials opinion pieces offer thought news reporting deeper understanding current events'

# %%
# spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
# spacy_stopwords.remove('not')
nlp.
# Out:
# set()
