# %% [markdown]
# ### Load some modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
sub_dir = '/Users/dominicbates/Documents/GitHub/app-review-classifier/'
os.chdir(sub_dir)
import app_review_classifier.text_processing as processing

# %% [markdown]
# ### Load review data

# %%
def split_sample(df, frac_train = 0.9, frac_validate = 0.1):
  
    # Shuffle dataframe
    df_shuffled = df.sample(frac=1, random_state=123).reset_index(drop=True)
    
    # Indexes
    train_index = int(len(df)*frac_train)
    validate_index = int(len(df)*(frac_train+frac_validate))

    # Sample dataframe
    df_train = df_shuffled[:train_index]
    df_validate = df_shuffled[train_index:validate_index]
    df_test = df_shuffled[validate_index:]
    
    return df_train, df_validate, df_test

# %%
df = pd.read_csv('/Users/dominicbates/Documents/GitHub/app-review-classifier/data/classified_sample_2nd_sep.csv')

# %%
m_sample = (df['Your Name'] == 'Dom')
cleaned_df = df[m_sample] 

# Remove nulls
cleaned_df = cleaned_df[pd.notnull(cleaned_df['Category'])]
cleaned_df = cleaned_df[pd.notnull(cleaned_df['Sentiment'])].reset_index(drop=True)

# %%
cleaned_df.head()
# Out:
#         Date  Rating                                         Title  \
# 0  15-Apr-20       5                    Beautiful App - Login Woes
# 1  05-Sep-19       1  World in Brief is repeated in Today’s Agenda
# 2  20-Sep-21       5                                   Being Brief
# 3  20-Aug-22       5                                     ESSENTIAL
# 4  08-Mar-21       1                                           NaN
#
#              App       OS                                             Review  \
# 0  The Economist      iOS  Love the app, beautiful and love the audio int...
# 1       Espresso      iOS  The Espresso was good earlier, reading it used...
# 2  The Economist      iOS  The Economist is to be complimented on its “Mo...
# 3  The Economist      iOS  Good writing is good thinking with ink (or pix...
# 4  The Economist  Android                   You need to pay for everything?!
#
#                        uniqueid  row_created_date Category Sentiment Your Name
# 0  apple_The Economist_sirbeeth  01/09/2022 10:00        B         M       Dom
# 1       apple_Espresso_Abyss312  01/09/2022 10:00        J         N       Dom
# 2    apple_The Economist_DVJake  01/09/2022 12:00        J         P       Dom
# 3   apple_The Economist_jhatpro  01/09/2022 12:00        J         P       Dom
# 4  google_The Economist_Swadesh  01/09/2022 10:00        O         N       Dom

# %% [markdown]
# ### Do text processing and embedding

# %%
cleaner = processing.TextCleaner(config = {'stop_words':True,
                                           'ngrams':True,
                                           'lemmatization':True})

# Train on full sample
cleaned_text_all = cleaner.process_raw_text(df['Review'],train_ngrams = True)

# Apply to cleaned sample
cleaned_text = cleaner.process_raw_text(cleaned_df['Review'])
# Out:
# Cleaning up text and removing stopwords...
# - Text cleaned in: 0.18 seconds
#
# Training ngrams...
# - Training done in: 0.98 seconds
#
# Loading spacy model...
# - Model loaded in: 0.61 seconds
#
# Lemmatizing...
# - Lemmatizing done in: 23.57 seconds
# Cleaning up text and removing stopwords...
# - Text cleaned in: 0.01 seconds
#
# Loading spacy model...
# - Model loaded in: 0.51 seconds
#
# Lemmatizing...
# - Lemmatizing done in: 1.27 seconds

# %%
embedder_w2v = processing.Embedder(method='word2vec')
embedder_tfidf = processing.Embedder(method='tfidf')

embedder_w2v.fit(cleaned_text_all)
embedder_tfidf.fit(cleaned_text_all)
# Out:
# Fitting word2vec model...
# - Setting up model...
# - Done!
# - Building Vocab...
# - Built!
# - Training Model...
# - Trained!
# Fitting tfidf model...
# - Done!

# %%
# Split sample
df_train, ignore, df_test = split_sample(cleaned_df, 0.9, 0)

train_X = embedder_w2v.apply(cleaner.process_raw_text(df_train['Review']))
test_X = embedder_w2v.apply(cleaner.process_raw_text(df_test['Review']))
# Out:
# Cleaning up text and removing stopwords...
# - Text cleaned in: 0.01 seconds
#
# Loading spacy model...
# - Model loaded in: 0.55 seconds
#
# Lemmatizing...
# - Lemmatizing done in: 1.21 seconds
# Cleaning up text and removing stopwords...
# - Text cleaned in: 0.0 seconds
#
# Loading spacy model...
# - Model loaded in: 0.57 seconds
#
# Lemmatizing...
# - Lemmatizing done in: 0.15 seconds

# %%
df.sample(frac=1).reset_index(drop=True)
# Out:
#            Date  Rating                          Title            App  \
# 0     08-May-20       4                            NaN  The Economist
# 1     02-Aug-19       5                            NaN       Espresso
# 2     27-Jun-18       5                            NaN       Espresso
# 3     11-Mar-22       4                            NaN       Espresso
# 4     23-Jul-22       2          No Split View Support  The Economist
# ...         ...     ...                            ...            ...
# 9110  25-Jan-19       5                     Quick read       Espresso
# 9111  20-Nov-21       3                            NaN  The Economist
# 9112  06-Jul-20       1                 Waste of money  The Economist
# 9113  01-Aug-22       1  Racist and Propagandist media  The Economist
# 9114  01-Jan-21       5                Used to be good  The Economist
#
#            OS                                             Review  \
# 0     Android                                  Very informative.
# 1     Android                                 best news app ever
# 2     Android  A well-degined app that allows me to start my ...
# 3     Android  Despite occasional bugs, I like the app and en...
# 4         iOS  The app doesn’t support split view / multitask...
# ...       ...                                                ...
# 9110      iOS  A good quick but thorough update on the world ...
# 9111  Android  Reports are not fair and balanced. They promot...
# 9112      iOS  Just got billed $189.99 for renewal. For past ...
# 9113      iOS  They used to be good at telling economical iss...
# 9114      iOS  The app is horribly disappointing.\nContent is...
#
#                                uniqueid  row_created_date Category Sentiment  \
# 0     google_The Economist_philippe lam  01/09/2022 10:00      NaN       NaN
# 1         google_Espresso_A Google user  01/09/2022 10:00      NaN       NaN
# 2         google_Espresso_A Google user  01/09/2022 10:00      NaN       NaN
# 3       google_Espresso_Hesam Shahriari  01/09/2022 10:00      NaN       NaN
# 4         apple_The Economist_StevenNYC  01/09/2022 10:00      NaN       NaN
# ...                                 ...               ...      ...       ...
# 9110            apple_Espresso_big AL G  01/09/2022 10:00      NaN       NaN
# 9111     google_The Economist_Ivan Shim  01/09/2022 10:00        J         N
# 9112     apple_The Economist_BlueGrouse  01/09/2022 12:00      NaN       NaN
# 9113    apple_The Economist_Dead waffle  01/09/2022 10:00      NaN       NaN
# 9114       apple_The Economist_brawmitt  01/09/2022 10:00      NaN       NaN
#
#      Your Name
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 9110       NaN
# 9111       Dom
# 9112       NaN
# 9113       NaN
# 9114       NaN
#
# [9115 rows x 11 columns]
